# %% [markdown]
# <a href="https://colab.research.google.com/github/BDonadelli/Codigos-em-financas/blob/main/noticias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
#busca = input()

# %%
URLs = [
        'https://bmcnews.com.br/categoria/analises/', # BMC Analises
        'https://bmcnews.com.br/categoria/economia/', # BMC Economia
        'https://bmcnews.com.br/categoria/mercados/', # BMC Mercados
        'https://bmcnews.com.br/ultimas-noticias/', # BMC ultimas noticias
        'https://comoinvestir.thecap.com.br/t/mercado-financeiro',
        'https://comoinvestir.thecap.com.br/c/noticias',
        'https://comoinvestir.thecap.com.br/c/renda-fixa',
        'https://comoinvestir.thecap.com.br/c/renda-variavel'
        ]

for url in URLs :
  response = requests.get(url)
  soup = BeautifulSoup(response.text, 'html.parser')
  headlines = soup.find('body').find_all('h3')
  for x in headlines:
    print(x.text.strip())

url='https://www.infomoney.com.br/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
headlines = soup.find_all("span", class_="hl-title hl-title-4")
for x in headlines:
    print(x.text.strip())

url='https://www.infomoney.com.br/ultimas-noticias/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
headlines = soup.find_all("span", class_="hl-title hl-title-2")
for x in headlines:
    print(x.text.strip())

url='https://valorinveste.globo.com/ultimas-noticias/'
url='https://valorinveste.globo.com/objetivo/hora-de-investir/'

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
headlines = soup.find('body').find_all('h2')
for x in headlines:
  print(x.text.strip())

url='https://financenews.com.br/category/nao-deixe-de-ler/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
headlines = soup.find('body').find_all('h3')
for x in headlines:
  print(x.text.strip())

url='https://financenews.com.br/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
headlines = soup.find('body').find_all('h3')
for x in headlines:
  print(x.text.strip())

url='https://www.dadosdemercado.com.br/noticias'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
headlines = soup.find('body').find_all('h3')
for x in headlines:
  for y in x.find_all('a') :
    print(y.contents[0])
# Out:
# MGLU3: “Podemos estar diante de uma nova tendência de queda do ativo”, avalia analista
# Apesar da previsão de queda da Selic, CIO da 3R Investimentos avalia que ainda não é hora de investir no varejo
# IPCA de Junho: economista avalia que números não mudam projeções e vê queda de juros ainda em agosto
# “O Brasil só dá sinal de expansão da dívida” diz Estrategista-chefe da SaraInvest
# Estrategista da RB Investimentos avalia IPCA e chance de queda da Selic em agosto; confira
# Temos razões para acreditar que a reforma tributária vai avançar, diz economista-chefe
# PETR4: “A tendência é clara de alta para os ativos”, diz analista
# VALE3: “Vejo sinais de recuperação para Vale”, avalia analista
# “Achamos que o Brasil será um país que vai empobrecer ao longo do tempo” diz CIO da 3R Investimentos
# PIB brasileiro: “Ainda vamos ter bons meses pela frente”, avalia economista
# ITUB4: analista avalia ações e prevê queda para os ativos na faixa dos R$ 25,12
# Smart Fit (SMFT3): “acho que tem espaço para chegar aos R$ 19,25”, diz analista
# Ibovespa fecha em alta com ganhos da Petrobras
# Taurus (TASA4) lança 1ª pistola em polímero e calibre .45 nos EUA
# Temporada de balanços 2T23: Confira o calendário de divulgação das companhias listadas na B3
# É verdade que na Califórnia quem furta até US$ 950 não é preso?
# Até R$ 21 milhões: conheça as 5 bolsas de grife mais caras do mundo
# Focus: Mercado corta estimativa da inflação de 2023 pela 8ª semana seguida
# Ibovespa Sobe +0,43% apÃ³s IBC-Br; RAIZ4 +3,68%
# Focus: ProjeÃ§Ã£o para a InflaÃ§Ã£o de 2023 Ã© Mantida em 4,95% e Estimativa do PIB Sobe para 2,24%
# Quem foi Sam Zell? O LendÃ¡rio Investidor ImobiliÃ¡rio
# Com Aumento de Juros, Construtoras Temem RetraÃ§Ã£o na Venda de ImÃ³veis
# Mapa dos Dividendos
# TelefÃ´nica Brasil (VIVT3) PagarÃ¡ R$ 405 MilhÃµes em JCP em 2024
# Ibovespa Sobe +0,43% apÃ³s IBC-Br; RAIZ4 +3,68%
# CalendÃ¡rio EconÃ´mico: IBC-Br e PIB da China
# Cemig (CMIG4): Pzena Eleva PosiÃ§Ã£o nas AÃ§Ãµes da Empresa para 5,00%
# Trisul (TRIS3) Tem Alta Anual de 61,5% nas Vendas LÃ­quidas no 2T23, a R$ 331 Mi
# Como Investir: Renda Fixa vs Gerador de Renda
# Investimento da Petrobras (PETR4) em Novo Plano Deve ser Semelhante ao Atual, diz CEO
# TelefÃ´nica Brasil (VIVT3) PagarÃ¡ R$ 405 MilhÃµes em JCP em 2024
# Ibovespa Sobe +0,43% apÃ³s IBC-Br; RAIZ4 +3,68%
# Focus: ProjeÃ§Ã£o para a InflaÃ§Ã£o de 2023 Ã© Mantida em 4,95% e Estimativa do PIB Sobe para 2,24%
# Quem foi Sam Zell? O LendÃ¡rio Investidor ImobiliÃ¡rio
# Com Aumento de Juros, Construtoras Temem RetraÃ§Ã£o na Venda de ImÃ³veis
# Mesmo com patrimônio remunerado pelo CDI, banco vê juros mais baixos como vetor de crescimento
# Petrobras: as novas falas do CEO Jean Paul Prates que reduziram as preocupações de curto prazo com a estatal
# Banco Central sinaliza regulação para criptomoedas do tipo DeFi
# Enjoei adquire site de artesanato e produtos personalizados Elo7; ações disparam
# PRIO: início de produção no poço ODP5 é novo marco e reforça histórico de boa execução da petrolífera
# Prinz capta R$ 100 milhões em uma semana em fundo que investe em FIDCs; atrasos e inadimplência normalizam
# Fim da exclusividade? cotistas de FII que aluga agências para o Banco do Brasil querem outros locatários
# Ministério prevê pagamento do piso da enfermagem a partir de agosto
# PGR pede acesso a postagens de Bolsonaro sobre eleições
# Credores da Light sinalizam que podem rejeitar plano de recuperação judicial
# Saída da Rússia do acordo do Mar Negro provoca volatilidade no mercado de grãos
# Produção industrial nos EUA cai 0,5% em junho ante maio; projeção era de estabilidade
# Vendas no varejo dos EUA sobem 0,2% em junho ante maio, abaixo do esperado
# ‘Desenrola’: veja o que já se sabe sobre o programa de renegociação de dívidas
# 'Desenrola': quais bancos vão participar? Veja lista e condições
# Sem tempo ruim: setor de luxo dribla inflação e juros altos e sobe 30% em 2023
# Como fica a taxação de investimentos no exterior com o andamento da reforma tributária?
# Reforma nova, casa velha: o que as mudanças tributárias vão fazer com os mercados?
# Vale a pena comprar Bitcoin a US$ 30 mil? Entenda a tese que projeta nova disparada do BTC
# Reforma Tributária: qual será o impacto para o consumidor de seguros?
# Mercados nesta quinta, minério, petróleo, notícia da Cyrela, Tenda, Oi, Braskem e outros destaques
# Eventos que podem impactar a Bolsa na semana
# Mercados nesta sexta, minério, petróleo, JCP do Santander, notícia da Camil, Petrobras e outros destaques
# Frasle Mobility (FRAS3) anuncia pagamento de juros sobre o capital próprio
# Trisul (TRIS3) reporta alta de 61,5% nas vendas líquidas no 2T23, na base anual
# Aura (AURA33) atualiza programa de exploração e avanços planejados para 2023
# Prévia da Helbor (HBOR3): vendas brutas totais no 2T23 atingem R$ 367 milhões
# Três lições do cofundador do Netflix para criar uma cultura de sucesso
# Moody’s: combinação de negócios com Hermes Pardini fortalece perfil de crédito da Fleury
# Fitch eleva rating da Log-In (LOGN3)
# Fitch afirma rating da Pague Menos (PGMN3)
# Dividendo da Duke Energy (DUKB34)
# Dividendo da Metlife (METB34)
# Dividendo da Equinor (E1QN34)
# Dividendo da General Electric (GEOO34)
# Dividendo da AT&T (ATTB34)
# Dividendo da Dupont (DDNB34)
# Assista ao estudo Ibovespa, Petr4, Prio3, Rrrp3, Vale3, Cmin3, Usim5 e de Radl3
# Assista ao estudo do Ibov, Vale3, Petr4, Ggbr4, Goau4, Hapv3, Pcar3, Soja3 e de outras ações
# Assista ao estudo do Ibovespa, Petr4, Vale3, Cpfe3, Elet3, Flry3, Tots3, Mrfg3, Kepl3 e de outros papéis
# Prévia da Cyrela, Tenda, Even e Melnick, notícia da Oi, Braskem e de outras companhias
# Atualização das 13h30: BB Seguridade, Porto, Caixa Seguridade e outros destaques
# Mercados nesta quinta, minério, petróleo, notícia da Cyrela, Tenda, Oi, Braskem e outros destaques
# Eventos que podem impactar a Bolsa na semana
# Mercados nesta sexta, minério, petróleo, JCP do Santander, notícia da Camil, Petrobras e outros destaques
# Enjoei adquire Elo7, maior plataforma de produtos autorais do Brasil
# EDP inicia período de compra de ações de minoritários
# Marisa Lojas conclui etapas importantes de reestruturação operacional
# JSL adquire FSJ Logística e expande operações no varejo e e-commerce
# Light S.A. apresenta Plano de Recuperação Judicial
# Azul formaliza segundo aditamento à emissão de debêntures
# CCR adquire participação adicional na Concessionária VLT Carioca
# Sanepar anuncia vencedora de licitação para serviço de esgotamento sanitário
# Azul conclui troca de dívidas e emissão de títulos
# Vice-presidente de Produtos da Cogna renuncia ao cargo
# BRF aprova emissão de ações no valor de R$ 5,4 bilhões
# MRV precifica oferta de ações a R$ 12,80 por ação
# Oferta pública de aquisição de ações da BR Properties
# BRF aprova emissão de ações no valor de R$ 5,4 bilhões
# Azul anuncia oferta de títulos de dívida com garantia prioritária

# %%
# data = '''<div class="image">
#         <a href="http://www.example.com/eg1">Content1<img
#         src="http://image.example.com/img1.jpg" /></a>
#         </div>
#         <div class="image">
#         <a href="http://www.example.com/eg2">Content2<img
#         src="http://image.example.com/img2.jpg" /> </a>
#         </div>'''

# soup = BeautifulSoup(data)

# for div in soup.findAll('div', attrs={'class':'image'}):
#     print(div.find('a')['href'])
#     print(div.find('a').contents[0])
#     print(div.find('img')['src'])
#     print()
