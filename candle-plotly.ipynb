# %%
import pandas as pd
import numpy as np
from datetime import timedelta, time,datetime
import os

from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
from tvDatafeed import TvDatafeed, Interval

username = 'jdonadelli'
password = open('/home/yair/GHub/Codigos-em-financas/passwd.txt', 'r').read()

tv = TvDatafeed(username, password)
# Out:
# error while signin
# you are using nologin method, data you access may be limited

# %%
df = tv.get_hist(symbol='PETR4',exchange='BMFBOVESPA',interval=Interval.in_5_minute, n_bars= 5000)
df['time'] = df.index
df
# Out:
#                                symbol   open   high    low  close    volume  \
# datetime
# 2023-12-07 16:30:00  BMFBOVESPA:PETR4  33.57  33.58  33.54  33.56  142000.0
# 2023-12-07 16:35:00  BMFBOVESPA:PETR4  33.56  33.58  33.53  33.58  418300.0
# 2023-12-07 16:40:00  BMFBOVESPA:PETR4  33.57  33.62  33.56  33.58  372300.0
# 2023-12-07 16:45:00  BMFBOVESPA:PETR4  33.57  33.58  33.54  33.56  117600.0
# 2023-12-07 16:50:00  BMFBOVESPA:PETR4  33.55  33.55  33.52  33.53  249200.0
# ...                               ...    ...    ...    ...    ...       ...
# 2024-02-27 16:50:00  BMFBOVESPA:PETR4  42.49  42.54  42.48  42.51  151300.0
# 2024-02-27 16:55:00  BMFBOVESPA:PETR4  42.50  42.58  42.50  42.55  147700.0
# 2024-02-27 17:00:00  BMFBOVESPA:PETR4  42.55  42.56  42.48  42.49  156000.0
# 2024-02-27 17:05:00  BMFBOVESPA:PETR4  42.48  42.58  42.48  42.55  332900.0
# 2024-02-27 17:10:00  BMFBOVESPA:PETR4  42.54  42.56  42.54  42.55   28100.0
#
#                                    time
# datetime
# 2023-12-07 16:30:00 2023-12-07 16:30:00
# 2023-12-07 16:35:00 2023-12-07 16:35:00
# 2023-12-07 16:40:00 2023-12-07 16:40:00
# 2023-12-07 16:45:00 2023-12-07 16:45:00
# 2023-12-07 16:50:00 2023-12-07 16:50:00
# ...                                 ...
# 2024-02-27 16:50:00 2024-02-27 16:50:00
# 2024-02-27 16:55:00 2024-02-27 16:55:00
# 2024-02-27 17:00:00 2024-02-27 17:00:00
# 2024-02-27 17:05:00 2024-02-27 17:05:00
# 2024-02-27 17:10:00 2024-02-27 17:10:00
#
# [5000 rows x 7 columns]

# %%
inicio = datetime(2023,12,20).date()
fim = datetime(2024,2,26).date()
df_cut = df[(df.index.date >= inicio) & (df.index.date <= fim)]
df_cut
# Out:
#                                symbol   open   high    low  close     volume  \
# datetime
# 2023-12-20 10:05:00  BMFBOVESPA:PETR4  36.37  36.43  36.32  36.33  5980500.0
# 2023-12-20 10:10:00  BMFBOVESPA:PETR4  36.33  36.42  36.32  36.36   315500.0
# 2023-12-20 10:15:00  BMFBOVESPA:PETR4  36.36  36.37  36.29  36.34  1094800.0
# 2023-12-20 10:20:00  BMFBOVESPA:PETR4  36.34  36.44  36.34  36.40   515800.0
# 2023-12-20 10:25:00  BMFBOVESPA:PETR4  36.41  36.48  36.32  36.47  1255600.0
# ...                               ...    ...    ...    ...    ...        ...
# 2024-02-26 17:30:00  BMFBOVESPA:PETR4  42.68  42.73  42.61  42.64   442500.0
# 2024-02-26 17:35:00  BMFBOVESPA:PETR4  42.64  42.72  42.64  42.68   485300.0
# 2024-02-26 17:40:00  BMFBOVESPA:PETR4  42.68  42.71  42.68  42.68   282400.0
# 2024-02-26 17:45:00  BMFBOVESPA:PETR4  42.68  42.69  42.66  42.68   287200.0
# 2024-02-26 17:50:00  BMFBOVESPA:PETR4  42.68  42.70  42.60  42.69   409700.0
#
#                                    time
# datetime
# 2023-12-20 10:05:00 2023-12-20 10:05:00
# 2023-12-20 10:10:00 2023-12-20 10:10:00
# 2023-12-20 10:15:00 2023-12-20 10:15:00
# 2023-12-20 10:20:00 2023-12-20 10:20:00
# 2023-12-20 10:25:00 2023-12-20 10:25:00
# ...                                 ...
# 2024-02-26 17:30:00 2024-02-26 17:30:00
# 2024-02-26 17:35:00 2024-02-26 17:35:00
# 2024-02-26 17:40:00 2024-02-26 17:40:00
# 2024-02-26 17:45:00 2024-02-26 17:45:00
# 2024-02-26 17:50:00 2024-02-26 17:50:00
#
# [4138 rows x 7 columns]

# %%
from DT_feriados import feriados
lista = feriados(inicio,fim)
lista
# Out:
# array(['2023-12-25T00:00:00.000000000', '2024-01-01T00:00:00.000000000',
#        '2024-02-12T00:00:00.000000000', '2024-02-13T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
import plotly.io as pio
pio.renderers.default = 'vscode'

# %%
fig = make_subplots(rows=2,cols=1,shared_xaxes=False,vertical_spacing=0.15, row_heights=[.8,.2],
                    subplot_titles=('OHLC','Volume'))

fig.add_trace(go.Candlestick(x=df_cut.index,
                             open=df_cut['open'],
                             high=df_cut['high'],
                             low=df_cut['low'],
                             close=df_cut['close'],
                             showlegend=False),row=1,col=1)

fig.add_trace(go.Bar(x=df_cut.index,  y= df_cut['volume'],
                     marker_color='red',
                     showlegend=False),row=2,col=1)

fig.add_trace(go.Bar(x=df_cut.index, y=df_cut['volume'], 
                     showlegend=False, marker=dict(color='#FF0000')), row=2, col=1)

# fig.update_xaxes(rangebreaks=[
#     dict(bounds=["sat", "sun"], pattern="day of week"), 
#     # dict(bounds=[18, 10], pattern="hour"),  
#     # dict(values=lista)
#     ])


fig.update_layout(xaxis_rangeslider_visible=False, height=600, 
                  margin=dict(l=30,r=30,t=30,b=30))

fig.show()

# %%
list(pd.bdate_range(start=inicio, end=fim, freq="C", weekmask="Sat Sun").date)
# Out:
# [datetime.date(2024, 2, 24), datetime.date(2024, 2, 25)]
