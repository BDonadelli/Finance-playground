# %%
import yfinance as yf
import pandas as pd

# %% [markdown]
# seleciona os codigos do indice amplo

# %%
url='https://raw.githubusercontent.com/BDonadelli/Codigos-em-financas/main/data/Cart_IBrA.csv'
ibra = pd.read_csv(url, sep =';' , encoding='latin-1' , decimal=',' , thousands='.' , 
                   skiprows=[0],skipfooter=2,engine='python', index_col=False)
tickers = list(ibra['Código'].values)
tickers.sort()
tickers_string = ' '.join([ticker + '.SA' for ticker in tickers])
codigos = yf.Tickers(tickers_string)

# %% [markdown]
# coleta dados anuais

# %%
df_data = pd.concat([codigos.tickers[tickers[0]+'.SA'].financials,
                     codigos.tickers[tickers[0]+'.SA'].cashflow,
                     codigos.tickers[tickers[0]+'.SA'].balance_sheet])

# %%
df_data = pd.concat([codigos.tickers[tickers[0]+'.SA'].financials,
                     codigos.tickers[tickers[0]+'.SA'].cashflow,
                     codigos.tickers[tickers[0]+'.SA'].balance_sheet])
colunas = [(tickers[0][:5],str(df_data.columns[i].year)) for i in range(len(df_data.columns))]
df_data.columns=pd.MultiIndex.from_tuples(colunas)

for papel in tickers[1:] :
    df_aux = pd.concat([codigos.tickers[papel+'.SA'].financials,
                        codigos.tickers[papel+'.SA'].cashflow,
                        codigos.tickers[papel+'.SA'].balance_sheet])
    # print(papel)
    colunas = [(papel[:5],str(df_aux.columns[i].year)) for i in range(len(df_aux.columns))]
    df_aux.columns=pd.MultiIndex.from_tuples(colunas)  

    df_data = pd.merge(df_data, df_aux, left_index=True, right_index=True)

    # df_aux = None

# %%
df_data.head()
# Out:
#                                                            ABCB4  \
#                                                             2023
# Tax Effect Of Unusual Items                                  0.0
# Tax Rate For Calcs                                          0.34
# Net Income From Continuing Operation Net Minori...  1111073000.0
# Net Interest Income                                -1081792000.0
# Interest Expense                                    3762722000.0
#
#                                                                   \
#                                                             2022
# Tax Effect Of Unusual Items                                  0.0
# Tax Rate For Calcs                                      0.098805
# Net Income From Continuing Operation Net Minori...  1051044000.0
# Net Interest Income                                   76956000.0
# Interest Expense                                    2377630000.0
#
#                                                                   \
#                                                             2021
# Tax Effect Of Unusual Items                                  0.0
# Tax Rate For Calcs                                      0.049481
# Net Income From Continuing Operation Net Minori...   734231000.0
# Net Interest Income                                 -705884000.0
# Interest Expense                                    2951977000.0
#
#                                                                        \
#                                                             2020 2019
# Tax Effect Of Unusual Items                                  0.0  NaN
# Tax Rate For Calcs                                          0.34  NaN
# Net Income From Continuing Operation Net Minori...   449975000.0  NaN
# Net Interest Income                                -2470469000.0  NaN
# Interest Expense                                    5532423000.0  NaN
#
#                                                             ABEV3  \
#                                                              2023
# Tax Effect Of Unusual Items                           -13865000.0
# Tax Rate For Calcs                                          0.005
# Net Income From Continuing Operation Net Minori...  14501900000.0
# Net Interest Income                                  -778500000.0
# Interest Expense                                     2815700000.0
#
#                                                                    \
#                                                              2022
# Tax Effect Of Unusual Items                          -770100000.0
# Tax Rate For Calcs                                           0.34
# Net Income From Continuing Operation Net Minori...  14457900000.0
# Net Interest Income                                  -873000000.0
# Interest Expense                                     2892800000.0
#
#                                                                    \
#                                                              2021
# Tax Effect Of Unusual Items                          -106784400.0
# Tax Rate For Calcs                                          0.046
# Net Income From Continuing Operation Net Minori...  12671000000.0
# Net Interest Income                                  -994100000.0
# Interest Expense                                     1837400000.0
#
#                                                                         ...  \
#                                                              2020 2019  ...
# Tax Effect Of Unusual Items                          -308281300.0  NaN  ...
# Tax Rate For Calcs                                         0.1306  NaN  ...
# Net Income From Continuing Operation Net Minori...  11379400000.0  NaN  ...
# Net Interest Income                                  -163800000.0  NaN  ...
# Interest Expense                                     2112600000.0  NaN  ...
#
#                                                    YDUQ3               \
#                                                     2019         2020
# Tax Effect Of Unusual Items                          NaN   52912500.0
# Tax Rate For Calcs                                   NaN         0.34
# Net Income From Continuing Operation Net Minori...   NaN   98181000.0
# Net Interest Income                                  NaN -515291000.0
# Interest Expense                                     NaN  439223000.0
#
#                                                                  \
#                                                            2021
# Tax Effect Of Unusual Items                          43053520.0
# Tax Rate For Calcs                                         0.34
# Net Income From Continuing Operation Net Minori...  158171000.0
# Net Interest Income                                -570336000.0
# Interest Expense                                    526842000.0
#
#                                                                     \
#                                                               2022
# Tax Effect Of Unusual Items                         2583032.105305
# Tax Rate For Calcs                                        0.364269
# Net Income From Continuing Operation Net Minori...     -58244000.0
# Net Interest Income                                   -821660000.0
# Interest Expense                                       736183000.0
#
#                                                                  \
#                                                            2023
# Tax Effect Of Unusual Items                         -12826840.0
# Tax Rate For Calcs                                         0.34
# Net Income From Continuing Operation Net Minori...  152344000.0
# Net Interest Income                                -764489000.0
# Interest Expense                                    733375000.0
#
#                                                              ZAMP3  \
#                                                               2019
# Tax Effect Of Unusual Items                        -1493187.758063
# Tax Rate For Calcs                                        0.097143
# Net Income From Continuing Operation Net Minori...      48543000.0
# Net Interest Income                                    -69593000.0
# Interest Expense                                        82769000.0
#
#                                                                               \
#                                                            2020         2021
# Tax Effect Of Unusual Items                                 0.0   -2503080.0
# Tax Rate For Calcs                                         0.34         0.34
# Net Income From Continuing Operation Net Minori... -445607000.0 -273841000.0
# Net Interest Income                                 -44251000.0 -109934000.0
# Interest Expense                                    114675000.0  134959000.0
#
#
#                                                            2022 2023
# Tax Effect Of Unusual Items                          -7810140.0  NaN
# Tax Rate For Calcs                                         0.34  NaN
# Net Income From Continuing Operation Net Minori...  -55786000.0  NaN
# Net Interest Income                                -137862000.0  NaN
# Interest Expense                                    189685000.0  NaN
#
# [5 rows x 882 columns]

# %%
df_data.to_parquet("data/yf_financial_data_Y.parquet")

# %%
# import pyarrow.parquet as pq
# # Abrir o arquivo Parquet
# arquivo_parquet = pq.ParquetFile("data/teste.parquet")
# tabela_parquet = arquivo_parquet.read()
# df = tabela_parquet.to_pandas()

# %% [markdown]
# coleta dados trimestrais

# %%
df_data = pd.concat([codigos.tickers[tickers[0]+'.SA'].quarterly_financials,
                     codigos.tickers[tickers[0]+'.SA'].quarterly_cashflow,
                     codigos.tickers[tickers[0]+'.SA'].quarterly_balance_sheet])

colunas = [(tickers[0][:5],str(df_data.columns[i].month)+'/'+str(df_data.columns[i].year)) for i in range(len(df_data.columns))]
df_data.columns=pd.MultiIndex.from_tuples(colunas)

for papel in tickers[1:] :
    df_aux = pd.concat([codigos.tickers[papel+'.SA'].financials,
                        codigos.tickers[papel+'.SA'].cashflow,
                        codigos.tickers[papel+'.SA'].balance_sheet])
    # print(papel)
    colunas = [(papel[:5],str(df_aux.columns[i].month)+'/'+str(df_aux.columns[i].year)) for i in range(len(df_aux.columns))]
    df_aux.columns=pd.MultiIndex.from_tuples(colunas)  

    df_data = pd.merge(df_data, df_aux, left_index=True, right_index=True)

# %%
df_data.to_parquet("data/yf_financial_data_Q.parquet")
