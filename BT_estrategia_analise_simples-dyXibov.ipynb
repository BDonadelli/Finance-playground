# %%
import yfinance as yf
import pandas as pd

# %%
df_ibov = pd.read_csv("data/Cart_Ibov.csv")                      
df_ibov
# Out:
#    Código          Ação        Tipo  Qtde. Teórica  Part. (%)
# 0   VALE3          VALE  ON      NM     4196924316     12.618
# 1   PETR4     PETROBRAS  PN      N2     4566445852      8.782
# 2   ITUB4  ITAUUNIBANCO  PN      N1     4801593832      7.188
# 3   PETR3     PETROBRAS  ON      N2     2379877655      4.824
# 4   BBAS3        BRASIL  ON  EB  NM     2841898224      3.737
# ..    ...           ...         ...            ...        ...
# 81  PETZ3          PETZ  ON      NM      309729428      0.071
# 82  EZTC3         EZTEC  ON      NM       91514307      0.059
# 83  CVCB3    CVC BRASIL  ON      NM      525582771      0.048
# 84  PCAR3  P.ACUCAR-CBD  ON      NM      379430826      0.045
# 85  BHIA3   CASAS BAHIA  ON      NM       94843047      0.028
#
# [86 rows x 5 columns]

# %%
df_idiv = pd.read_csv("data/Cart_Idiv.csv")
df_idiv
# Out:
#     Código          Ação        Tipo  Qtde. Teórica  Part. (%)
# 0    CMIG4         CEMIG  PN      N1     2157902950      6.057
# 1    PETR4     PETROBRAS  PN      N2      682191496      5.919
# 2    GGBR4        GERDAU  PN  EB  N1     1419894314      5.842
# 3    PETR3     PETROBRAS  ON      N2      590840282      5.404
# 4    CPLE6         COPEL  PNB     N2     2545307750      5.073
# 5    BBAS3        BRASIL  ON  EB  NM      793164898      4.705
# 6    VALE3          VALE  ON      NM      284098114      3.854
# 7    BBSE3  BBSEGURIDADE  ON      NM      545114447      3.846
# 8   KLBN11    KLABIN S/A  UNT     N2      709464733      3.739
# 9    TRPL4  TRAN PAULIST  PN      N1      599901324      3.243
# 10   EGIE3  ENGIE BRASIL  ON      NM      378173990      3.230
# 11   JBSS3           JBS  ON      NM      673468323      3.189
# 12   VIVT3  TELEF BRASIL      ON  ER      300540563      3.134
# 13  SANB11  SANTANDER BR      UNT EJ      499015224      2.876
# 14   CSNA3  SID NACIONAL          ON      910710028      2.862
# 15   ITSA4        ITAUSA  PN      N1     1332917619      2.720
# 16   CXSE3  CAIXA SEGURI  ON      NM      784356029      2.611
# 17  TAEE11         TAESA  UNT     N2      331275965      2.533
# 18   GOAU4    GERDAU MET  PN      N1     1000961394      2.353
# 19   CPFE3  CPFL ENERGIA  ON      NM      284539416      2.127
# 20   CMIN3  CSNMINERACAO  ON      N2     1683234625      1.910
# 21   CMIG3         CEMIG  ON      N1      546807935      1.781
# 22   PSSA3  PORTO SEGURO  ON      NM      275140721      1.745
# 23   USIM5      USIMINAS  PNA     N1      780744795      1.727
# 24   BRAP4     BRADESPAR  PN      N1      380436831      1.726
# 25   POMO4     MARCOPOLO  PN      N2     1010243819      1.542
# 26  ALUP11        ALUPAR  UNT EDB N2      229590337      1.379
# 27   CSMG3        COPASA  ON      NM      285645639      1.317
# 28   AURE3         AUREN  ON      NM      457679426      1.157
# 29   FLRY3        FLEURY  ON      NM      365006180      1.097
# 30   UNIP6        UNIPAR      PNB EB       77320979      0.933
# 31   BRSR6      BANRISUL  PNB     N1      306453645      0.814
# 32   DIRR3    DIRECIONAL  ON      NM      163080575      0.778
# 33   CURY3      CURY S/A  ON      NM      182321209      0.729
# 34   LEVE3    METAL LEVE  ON      NM       80126895      0.574
# 35   KEPL3  KEPLER WEBER  ON      NM      267607296      0.573
# 36   ABCB4    ABC BRASIL  PN      N2      112596646      0.553
# 37   AGRO3    BRASILAGRO  ON      NM       96658494      0.551
# 38   GRND3      GRENDENE  ON      NM      406425647      0.522
# 39   BEEF3       MINERVA  ON      NM      395643098      0.515
# 40   EVEN3          EVEN  ON      NM      288501857      0.448
# 41   FESA4       FERBASA  PN      N1      245507832      0.435
# 42   JHSF3     JHSF PART  ON      NM      453565710      0.416
# 43   RANI3         IRANI  ON      NM      155753957      0.310
# 44   TASA4  TAURUS ARMAS  PN      N2      103750861      0.273
# 45   TGMA3         TEGMA  ON  EDJ NM       48503332      0.254
# 46   LAVV3         LAVVI  ON      NM      111931968      0.206
# 47   WIZC3        WIZ CO  ON      NM      114089234      0.174
# 48   ROMI3          ROMI  ON      NM       71729020      0.167
# 49   MTRE3  MITRE REALTY  ON      NM       79178852      0.077

# %%
## 10 maiores sem repetição (ON/PN/...) de empresa 
acoes = df_ibov.drop_duplicates(subset='Ação', keep='first').head(10)
acoes
# Out:
#    Código          Ação        Tipo  Qtde. Teórica  Part. (%)
# 0   VALE3          VALE  ON      NM     4196924316     12.618
# 1   PETR4     PETROBRAS  PN      N2     4566445852      8.782
# 2   ITUB4  ITAUUNIBANCO  PN      N1     4801593832      7.188
# 4   BBAS3        BRASIL  ON  EB  NM     2841898224      3.737
# 5   ELET3    ELETROBRAS  ON      N1     1980568384      3.552
# 6   BBDC4      BRADESCO  PN      N1     5146576868      3.331
# 7   B3SA3            B3  ON      NM     5602790110      2.972
# 8   WEGE3           WEG  ON      NM     1481593024      2.710
# 9   ABEV3     AMBEV S/A          ON     4394245879      2.492
# 10  ITSA4        ITAUSA  PN      N1     5372783971      2.430

# %%
## 10 maiores sem repetição (ON/PN/...) de empresa 
acoes_div = df_idiv.drop_duplicates(subset='Ação', keep='first').head(10)
acoes_div
# Out:
#     Código          Ação        Tipo  Qtde. Teórica  Part. (%)
# 0    CMIG4         CEMIG  PN      N1     2157902950      6.057
# 1    PETR4     PETROBRAS  PN      N2      682191496      5.919
# 2    GGBR4        GERDAU  PN  EB  N1     1419894314      5.842
# 4    CPLE6         COPEL  PNB     N2     2545307750      5.073
# 5    BBAS3        BRASIL  ON  EB  NM      793164898      4.705
# 6    VALE3          VALE  ON      NM      284098114      3.854
# 7    BBSE3  BBSEGURIDADE  ON      NM      545114447      3.846
# 8   KLBN11    KLABIN S/A  UNT     N2      709464733      3.739
# 9    TRPL4  TRAN PAULIST  PN      N1      599901324      3.243
# 10   EGIE3  ENGIE BRASIL  ON      NM      378173990      3.230

# %%
acoes = acoes["Código"].values
acoes = " ".join([i + '.SA' for i in acoes])
print(acoes)

tickers = yf.Tickers(acoes)
tickers.tickers
# Out:
# VALE3.SA PETR4.SA ITUB4.SA BBAS3.SA ELET3.SA BBDC4.SA B3SA3.SA WEGE3.SA ABEV3.SA ITSA4.SA
# {'VALE3.SA': yfinance.Ticker object <VALE3.SA>,
#  'PETR4.SA': yfinance.Ticker object <PETR4.SA>,
#  'ITUB4.SA': yfinance.Ticker object <ITUB4.SA>,
#  'BBAS3.SA': yfinance.Ticker object <BBAS3.SA>,
#  'ELET3.SA': yfinance.Ticker object <ELET3.SA>,
#  'BBDC4.SA': yfinance.Ticker object <BBDC4.SA>,
#  'B3SA3.SA': yfinance.Ticker object <B3SA3.SA>,
#  'WEGE3.SA': yfinance.Ticker object <WEGE3.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'ITSA4.SA': yfinance.Ticker object <ITSA4.SA>}

# %%
## preço fechamento de cada papel
dict_data = {}

for ticker in tickers.tickers.keys():
    dict_data[ticker] = tickers.tickers[ticker].history(period="max")

df_data = pd.DataFrame()

for ticker in dict_data.keys():
    df_aux = dict_data[ticker].rename(columns={"Close": ticker})
    df_data = df_data.join(df_aux[ticker], how="outer")

df_data.head()
# Out:
#                            VALE3.SA  PETR4.SA  ITUB4.SA  BBAS3.SA  ELET3.SA  \
# Date
# 2000-01-03 00:00:00-02:00  1.531955  1.548670       NaN  0.204414  8.971256
# 2000-01-04 00:00:00-02:00  1.495479  1.462999       NaN  0.194692  8.537531
# 2000-01-05 00:00:00-02:00  1.495479  1.448237       NaN  0.196687  8.879947
# 2000-01-06 00:00:00-02:00  1.495479  1.443229       NaN  0.199429  8.674498
# 2000-01-07 00:00:00-02:00  1.550192  1.449820       NaN  0.194942  8.811462
#
#                            BBDC4.SA  B3SA3.SA  WEGE3.SA  ABEV3.SA  ITSA4.SA
# Date
# 2000-01-03 00:00:00-02:00       NaN       NaN  0.120674       NaN  0.408163
# 2000-01-04 00:00:00-02:00       NaN       NaN  0.116440       NaN  0.369192
# 2000-01-05 00:00:00-02:00       NaN       NaN  0.116440  0.290351  0.399959
# 2000-01-06 00:00:00-02:00       NaN       NaN  0.105854  0.275633  0.406112
# 2000-01-07 00:00:00-02:00       NaN       NaN  0.105854  0.275633  0.404061

# %%
dict_data["WEGE3.SA"].head()
# Out:
#                                Open      High       Low     Close  Volume  \
# Date
# 2000-01-03 00:00:00-02:00  0.120674  0.121733  0.120674  0.120674  378560
# 2000-01-04 00:00:00-02:00  0.117499  0.117499  0.116440  0.116440   47320
# 2000-01-05 00:00:00-02:00  0.116440  0.116440  0.116440  0.116440       0
# 2000-01-06 00:00:00-02:00  0.105854  0.105854  0.105854  0.105854  250120
# 2000-01-07 00:00:00-02:00  0.106913  0.106913  0.105854  0.105854  135200
#
#                            Dividends  Stock Splits
# Date
# 2000-01-03 00:00:00-02:00        0.0           0.0
# 2000-01-04 00:00:00-02:00        0.0           0.0
# 2000-01-05 00:00:00-02:00        0.0           0.0
# 2000-01-06 00:00:00-02:00        0.0           0.0
# 2000-01-07 00:00:00-02:00        0.0           0.0

# %%
primeira_data =  df_data.dropna().index[0]
primeira_data
# Out:
# Timestamp('2008-01-02 00:00:00-0200', tz='America/Sao_Paulo')

# %%
df_ret = df_data.pct_change(fill_method=None)

# %% [markdown]
# #### DY

# %%
tickers.tickers
# Out:
# {'VALE3.SA': yfinance.Ticker object <VALE3.SA>,
#  'PETR4.SA': yfinance.Ticker object <PETR4.SA>,
#  'ITUB4.SA': yfinance.Ticker object <ITUB4.SA>,
#  'BBAS3.SA': yfinance.Ticker object <BBAS3.SA>,
#  'ELET3.SA': yfinance.Ticker object <ELET3.SA>,
#  'BBDC4.SA': yfinance.Ticker object <BBDC4.SA>,
#  'B3SA3.SA': yfinance.Ticker object <B3SA3.SA>,
#  'WEGE3.SA': yfinance.Ticker object <WEGE3.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'ITSA4.SA': yfinance.Ticker object <ITSA4.SA>}

# %%
tickers.tickers['VALE3.SA'].dividends
# Out:
# Date
# 2008-04-11 00:00:00-03:00    0.436585
# 2008-10-17 00:00:00-03:00    0.138520
# 2009-04-16 00:00:00-03:00    0.524586
# 2009-10-16 00:00:00-03:00    0.492036
# 2010-04-15 00:00:00-03:00    0.421661
# 2010-10-15 00:00:00-03:00    0.471881
# 2011-01-17 00:00:00-02:00    0.320048
# 2011-04-14 00:00:00-03:00    0.608247
# 2011-08-12 00:00:00-03:00    0.933403
# 2011-10-17 00:00:00-02:00    0.634329
# 2012-04-16 00:00:00-03:00    1.075280
# 2012-10-17 00:00:00-03:00    1.186520
# 2013-04-17 00:00:00-03:00    0.864045
# 2013-10-18 00:00:00-03:00    0.120605
# 2014-04-15 00:00:00-03:00    0.898904
# 2014-10-17 00:00:00-03:00    0.990870
# 2015-04-15 00:00:00-03:00    0.601761
# 2015-10-16 00:00:00-03:00    0.373610
# 2016-12-02 00:00:00-02:00    0.166294
# 2017-04-24 00:00:00-03:00    0.905572
# 2017-12-22 00:00:00-02:00    0.419912
# 2018-03-07 00:00:00-03:00    0.488511
# 2018-08-03 00:00:00-03:00    1.480362
# 2019-12-27 00:00:00-03:00    1.414364
# 2020-09-22 00:00:00-03:00    2.407510
# 2021-03-05 00:00:00-03:00    4.261646
# 2021-06-24 00:00:00-03:00    2.189670
# 2021-09-23 00:00:00-03:00    8.197239
# 2022-03-09 00:00:00-03:00    3.719256
# 2022-08-12 00:00:00-03:00    3.572057
# 2022-12-13 00:00:00-03:00    0.292013
# 2023-03-14 00:00:00-03:00    1.827646
# 2023-08-14 00:00:00-03:00    1.918472
# 2023-11-22 00:00:00-03:00    0.765771
# 2024-03-12 00:00:00-03:00    2.738548
# Name: Dividends, dtype: float64

# %%
df_dividends = pd.DataFrame()

for ticker in tickers.tickers.keys():
    df_dividends_aux = tickers.tickers[ticker].dividends.to_frame().rename(columns={"Dividends": ticker})
    df_dividends = df_dividends.join(df_dividends_aux, how='outer')

df_dividends['year'] = df_dividends.index.year  ## dividendos 
df_data["year"] = df_data.index.year            ## cotação

# %%
df_dividends_year = df_dividends.groupby("year").sum()
df_dividends_year.head()
# Out:
#       VALE3.SA  PETR4.SA  ITUB4.SA  BBAS3.SA  ELET3.SA  BBDC4.SA  B3SA3.SA  \
# year
# 2005  0.000000  0.383951       0.0  0.000000  0.000000  0.000000  0.000000
# 2006  0.000000  0.892450       0.0  0.000000  0.000000  0.000000  0.000000
# 2007  0.000000  0.908200       0.0  0.000000  0.000000  0.000000  0.000000
# 2008  0.575105  0.300500       0.0  0.000000  0.415780  0.413529  0.024332
# 2009  1.016622  1.051600       0.0  0.868431  1.547656  0.278886  0.110237
#
#       WEGE3.SA  ABEV3.SA  ITSA4.SA
# year
# 2005  0.000000  0.000000  0.000000
# 2006  0.000000  0.000000  0.000000
# 2007  0.000000  0.016302  0.004256
# 2008  0.054881  0.097491  0.028759
# 2009  0.058580  0.163877  0.100866

# %%
df_last_price = df_data.dropna().groupby("year").last() ## ultima cotação do ano a partir de 
df_last_price                                           ## quando todas estavam listadas concomitantemente
# Out:
#        VALE3.SA   PETR4.SA   ITUB4.SA   BBAS3.SA   ELET3.SA   BBDC4.SA  \
# year
# 2008  12.275032   6.770117   6.001259   1.097857  12.013124   7.676005
# 2009  22.583591  11.237776   9.785732   2.314057  17.860256   7.156854
# 2010  25.565081   8.607507  10.145067   2.840077  12.024575   6.609152
# 2011  19.227526   7.039939   9.001787   2.467814  10.061088   6.446023
# 2012  21.804316   6.547344   9.141557   3.060457   3.888767   7.593076
# 2013  18.971334   5.839355   9.985808   3.574447   4.700200   7.113438
# 2014  12.417724   3.656360  12.231735   3.985567   4.904463   8.918564
# 2015   7.783045   2.442434  10.763821   3.020895   4.870640   6.253560
# 2016  15.429234   5.420745  16.142244   6.305262  19.288071  10.862492
# 2017  25.263283   5.869132  21.077105   7.601027  16.353849  14.496794
# 2018  33.299137   8.624997  27.984833  12.087942  20.488823  18.829424
# 2019  35.723019  11.858408  30.745781  15.236710  32.828796  22.382412
# 2020  61.061317  11.135652  26.888134  12.116975  33.205177  18.976786
# 2021  64.036690  13.753672  18.443930  10.466120  32.553665  15.436623
# 2022  80.014046  18.930288  22.903736  14.453434  41.847427  13.693049
# 2023  73.894554  37.240002  32.593693  27.092237  42.430000  17.003189
# 2024  63.360001  40.529999  31.549999  27.709999  37.799999  13.640000
#
#        B3SA3.SA   WEGE3.SA   ABEV3.SA  ITSA4.SA
# year
# 2008   3.617771   1.350611   1.947184  1.512064
# 2009   7.449724   2.042161   3.567347  2.543422
# 2010   8.087690   2.466077   5.252921  2.929307
# 2011   2.087475   2.188397   6.789852  2.644104
# 2012   3.093369   3.224914  10.789708  2.600321
# 2013   2.545605   3.816991  11.335231  2.747030
# 2014   2.348042   4.979537  11.060327  3.261559
# 2015   2.780587   4.996227  13.315294  2.782550
# 2016   4.345269   5.312840  12.679603  3.988731
# 2017   6.124941   8.422247  16.916225  5.493658
# 2018   7.429834   8.107323  12.625371  7.273789
# 2019  12.157039  16.271563  15.728646  9.078918
# 2020  18.119505  35.843376  13.533035  7.836106
# 2021  10.244831  31.573645  13.920564  6.510109
# 2022  12.600919  37.525452  13.798742  7.293730
# 2023  14.310308  36.551147  13.730000  9.990555
# 2024  11.180000  38.549999  11.950000  9.530000

# %%
df_yield = df_dividends_year/df_last_price  * 100
df_yield.dropna(inplace=True)
df_yield
# Out:
#        VALE3.SA   PETR4.SA  ITUB4.SA   BBAS3.SA   ELET3.SA   BBDC4.SA  \
# year
# 2008   4.685161   4.438624  0.000000   0.000000   3.461048   5.387294
# 2009   4.501596   9.357724  0.000000  37.528503   8.665363   3.896768
# 2010   3.495166   9.447567  1.371287  62.912979  29.940783   4.266599
# 2011  12.981530  13.079943  6.512129  75.258988   8.717000   5.931720
# 2012  10.373176   7.662649  5.727165  53.123439  32.904030   4.649710
# 2013   5.190199   6.613231  5.024981  66.499291  30.255524   4.735193
# 2014  15.218361  26.452535  4.384439  41.650788   8.405650   5.702095
# 2015  12.531998   0.000000  8.406365  68.245890   0.000000  10.428508
# 2016   1.077785   0.000000  6.588929  14.491245   0.000000   6.293556
# 2017   5.246682   0.000000  4.741002  12.445212   0.000000   4.870298
# 2018   5.912685  10.626821  7.003794  12.543516   0.000000   3.798698
# 2019   3.959251   7.946775  5.906046  16.763659   2.615079   6.730973
# 2020   3.942774   0.004140  2.901131  12.188760   4.894972   3.023584
# 2021  22.875253  41.103439  4.915970  21.653316   7.367094   5.992315
# 2022   9.477494  79.778917  4.445301  16.847692   1.848393   3.048145
# 2023   6.105848  19.678627  3.855470  13.359340   0.520691   8.822163
# 2024   4.322203   0.000000  4.556339   2.288751   0.000000   0.556452
#
#       B3SA3.SA  WEGE3.SA   ABEV3.SA   ITSA4.SA
# year
# 2008  0.672569  4.063421   5.006768   1.901970
# 2009  1.479746  2.868531   4.593806   3.965760
# 2010  1.939429  1.781534   2.233234   5.065567
# 2011  8.341322  3.848981   3.204798  10.233562
# 2012  4.359454  2.265983   4.417765   7.416969
# 2013  6.447583  2.623270   2.268820   6.631708
# 2014  5.738186  2.474949   5.370366   3.303910
# 2015  9.579415  3.004988  11.866054  10.767999
# 2016  3.862983  2.722687   5.047477  10.762520
# 2017  2.463893  1.633721   3.192201   6.437223
# 2018  3.150044  1.947647   4.356308  10.019441
# 2019  2.205126  1.046058   3.119150   7.955573
# 2020  2.971604  0.605953   3.056964   4.481091
# 2021  7.645856  1.339725   4.887015   4.971499
# 2022  3.722792  1.374214   5.524417   7.566252
# 2023  2.669426  1.682027   5.318281   5.611430
# 2024  1.966655  0.922719   0.000000   4.134628

# %%
df_yield.mean()
# Out:
# VALE3.SA     7.758657
# PETR4.SA    13.893588
# ITUB4.SA     4.490609
# BBAS3.SA    31.047139
# ELET3.SA     8.211507
# BBDC4.SA     5.184357
# B3SA3.SA     4.071534
# WEGE3.SA     2.129789
# ABEV3.SA     4.321378
# ITSA4.SA     6.542771
# dtype: float64

# %%
df_yield.mean().mean()
# Out:
# 8.765132795347597

# %% [markdown]
# carteira de ações ano a ano com as 3 maiores pagadoras de dividendo do ano anterior

# %%
## retorno anual 
df_ret_year = df_last_price / df_last_price.shift(1) - 1

# %%
df_yield.iloc[0, :].nlargest(3)
# Out:
# BBDC4.SA    5.387294
# ABEV3.SA    5.006768
# VALE3.SA    4.685161
# Name: 2008, dtype: float64

# %%
strategy_return = []

for i in range(len(df_yield) - 1):
    stocks = df_yield.iloc[i, :].nlargest(3).index 
    strategy_return += [(df_ret_year[stocks].iloc[i + 1] / 3).sum() + 1]

# %%
df_global = df_ret_year / 10
df_final = pd.DataFrame(strategy_return, columns=['estrategia'],
                        index=df_global.index[1:]).cumprod()

df_final['ibov10'] = (df_global.sum(axis=1) + 1).cumprod()
df_final.plot()
# Out:
# <Axes: xlabel='year'>
