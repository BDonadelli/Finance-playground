# %%
##  Lê a pagina web da url

url = 'https://www.tesourodireto.com.br/json/br/com/b3/tesourodireto/service/api/treasurybondsinfo.json'

from selenium import webdriver
driver=webdriver.Chrome()
driver.get(url)

## separa o que interessa

page_source = driver.page_source
start = page_source.find("{")
end = page_source.rfind("}") + 1
json_text = page_source[start:end]

import json
data_json = json.loads(json_text)

# %%
driver.close()

# %%
## organiza a informação

import pandas as pd
nome , pr , pc , tr , tc = [],[],[],[],[]
td=pd.DataFrame()
for i in range(len(data_json["response"]["TrsrBdTradgList"])):
  nome.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['nm'])
  pr.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['untrRedVal'])
  pc.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['untrInvstmtVal'])
  tr.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['anulRedRate'])
  tc.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['anulInvstmtRate'])

td['título'] = nome
td['preço resgate'] = pr
td['preço compra'] = pc
td['taxa resgate'] = tr
td['taxa compra'] = tc

td['Ano'] = td['título'].str.extract(r'\b(\d{4})\b')
td = td.sort_values(by=['título','Ano'], ascending=True)
td.drop(['Ano'],axis=1,inplace=True)

td
# Out:
#                                          título  preço resgate  preço compra  \
# 20                          Tesouro Educa+ 2026        3424.30       3439.53
# 21                          Tesouro Educa+ 2027        3234.54       3252.58
# 23                          Tesouro Educa+ 2028        3056.78       3077.29
# 24                          Tesouro Educa+ 2029        2888.96       2911.63
# 25                          Tesouro Educa+ 2030        2726.61       2751.10
# 28                          Tesouro Educa+ 2031        2572.35       2598.39
# 29                          Tesouro Educa+ 2032        2425.22       2452.53
# 30                          Tesouro Educa+ 2033        2288.93       2317.31
# 31                          Tesouro Educa+ 2034        2161.01       2190.26
# 32                          Tesouro Educa+ 2035        2043.01       2072.99
# 34                          Tesouro Educa+ 2036        1929.33       1959.86
# 35                          Tesouro Educa+ 2037        1819.76       1850.64
# 36                          Tesouro Educa+ 2038        1713.90       1744.94
# 37                          Tesouro Educa+ 2039        1611.25       1642.28
# 38                          Tesouro Educa+ 2040        1511.76       1542.61
# 41                          Tesouro Educa+ 2041        1415.22       1445.71
# 42                          Tesouro Educa+ 2042        1326.39       1356.48
# 53      Tesouro IGPM+ com Juros Semestrais 2031        8176.52          0.00
# 16                           Tesouro IPCA+ 2026        3797.57          0.00
# 18                           Tesouro IPCA+ 2029        3239.76       3257.79
# 26                           Tesouro IPCA+ 2035        2296.47       2324.91
# 39                           Tesouro IPCA+ 2045        1245.15       1274.81
# 17      Tesouro IPCA+ com Juros Semestrais 2026        4269.18          0.00
# 19      Tesouro IPCA+ com Juros Semestrais 2030        4301.70          0.00
# 22      Tesouro IPCA+ com Juros Semestrais 2032        4294.05          0.00
# 27      Tesouro IPCA+ com Juros Semestrais 2035        4355.84       4396.10
# 33      Tesouro IPCA+ com Juros Semestrais 2040        4306.49       4358.99
# 40      Tesouro IPCA+ com Juros Semestrais 2045        4315.60          0.00
# 44      Tesouro IPCA+ com Juros Semestrais 2050        4238.57          0.00
# 46      Tesouro IPCA+ com Juros Semestrais 2055        4314.34       4384.94
# 5                        Tesouro Prefixado 2025         964.03          0.00
# 7                        Tesouro Prefixado 2026         861.40          0.00
# 8                        Tesouro Prefixado 2027         771.76        774.05
# 10                       Tesouro Prefixado 2029         617.02          0.00
# 12                       Tesouro Prefixado 2031         492.26        495.83
# 6   Tesouro Prefixado com Juros Semestrais 2025        1010.89          0.00
# 9   Tesouro Prefixado com Juros Semestrais 2027         982.67          0.00
# 11  Tesouro Prefixado com Juros Semestrais 2029         959.34          0.00
# 13  Tesouro Prefixado com Juros Semestrais 2031         939.08          0.00
# 14  Tesouro Prefixado com Juros Semestrais 2033         927.25          0.00
# 15  Tesouro Prefixado com Juros Semestrais 2035         915.25        921.98
# 43      Tesouro Renda+ Aposentadoria Extra 2030        1844.23       1872.79
# 45      Tesouro Renda+ Aposentadoria Extra 2035        1367.44       1396.43
# 47      Tesouro Renda+ Aposentadoria Extra 2040        1009.76       1036.96
# 48      Tesouro Renda+ Aposentadoria Extra 2045         743.67        767.99
# 49      Tesouro Renda+ Aposentadoria Extra 2050         552.97        574.28
# 50      Tesouro Renda+ Aposentadoria Extra 2055         410.07        428.27
# 51      Tesouro Renda+ Aposentadoria Extra 2060         302.85        318.07
# 52      Tesouro Renda+ Aposentadoria Extra 2065         224.49        237.10
# 0                            Tesouro Selic 2024       15252.12          0.00
# 1                            Tesouro Selic 2025       15254.72          0.00
# 2                            Tesouro Selic 2026       15248.10          0.00
# 3                            Tesouro Selic 2027       15222.98      15232.85
# 4                            Tesouro Selic 2029       15143.30      15156.18
#
#     taxa resgate  taxa compra
# 20        6.3400        6.220
# 21        6.2500        6.130
# 23        6.1800        6.060
# 24        6.1300        6.010
# 25        6.1100        5.990
# 28        6.1000        5.980
# 29        6.1000        5.980
# 30        6.0900        5.970
# 31        6.0800        5.960
# 32        6.0600        5.940
# 34        6.0500        5.930
# 35        6.0500        5.930
# 36        6.0600        5.940
# 37        6.0800        5.960
# 38        6.1100        5.990
# 41        6.1500        6.030
# 42        6.1800        6.060
# 53        6.1700        0.000
# 16        6.7000        0.000
# 18        6.3100        6.190
# 26        6.1000        5.980
# 39        6.2200        6.100
# 17        6.7000        0.000
# 19        6.1400        0.000
# 22        6.1400        0.000
# 27        6.1300        6.010
# 33        6.0700        5.950
# 40        6.1800        0.000
# 44        6.1900        0.000
# 46        6.1600        6.040
# 5        10.8000        0.000
# 7        11.6200        0.000
# 8        11.6800       11.560
# 10       11.8100        0.000
# 12       11.8800       11.760
# 6        10.8600        0.000
# 9        11.6800        0.000
# 11       11.7900        0.000
# 13       11.8600        0.000
# 14       11.7900        0.000
# 15       11.8100       11.690
# 43        6.1300        6.010
# 45        6.1500        6.030
# 47        6.1800        6.060
# 48        6.2100        6.090
# 49        6.2000        6.080
# 50        6.2000        6.080
# 51        6.2100        6.090
# 52        6.2100        6.090
# 0         0.0355        0.000
# 1        -0.0309        0.000
# 2         0.0180        0.000
# 3         0.0770        0.067
# 4         0.1600        0.150

# %%
# Gravar os dados em um arquivo .json
# os dados da ultima atualização ficam disponiveis no github

with open('data/tesouro_direto.json', 'w', encoding='utf-8') as json_file:
    json.dump(data_json, json_file, ensure_ascii=False, indent=4)

print("Dados gravados em 'tesouro_direto.json'")
print("Dados disponíveis em ")
print("https://raw.githubusercontent.com/BDonadelli/Finance-playground/main/data/tesouro_direto.json")
# Out:
# Dados gravados em 'tesouro_direto.json'
# Dados disponíveis em
# https://raw.githubusercontent.com/BDonadelli/Finance-playground/main/data/tesouro_direto.json

# %%
## escreva numa planilha (privada)

import gspread
from oauth2client.service_account import ServiceAccountCredentials

scope = ['https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/spreadsheets']
jfile = 'carteira-328314-d38dcc8ee3e4.json'

credentials = ServiceAccountCredentials.from_json_keyfile_name(jfile, scope)
gc = gspread.authorize(credentials)


from datetime import datetime

# %%
titulo_planilha = 'Investimentos'
planilha = gc.open(titulo_planilha)
atualiza_saldos = True
pagina = planilha.worksheet('Renda Fixa')

# %%
from datetime import date
today = date.today().strftime('%d/%m/%Y')

linha = int(input('linha da celula inicial 81)'))
pagina.update(range_name= 'a'+str(linha),  values=[[today]] )

pagina.update(range_name='a'+str(linha+1),values=[td.columns.values.tolist()] + td.values.tolist())
