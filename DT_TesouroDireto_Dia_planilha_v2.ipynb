# %%
##  Lê a pagina web da url

url = 'https://www.tesourodireto.com.br/json/br/com/b3/tesourodireto/service/api/treasurybondsinfo.json'

from selenium import webdriver
driver=webdriver.Chrome()
driver.get(url)

## separa o que interessa

page_source = driver.page_source
start = page_source.find("{")
end = page_source.rfind("}") + 1
json_text = page_source[start:end]

import json
data_json = json.loads(json_text)

# %%
driver.close()

# %%
## organiza a informação

import pandas as pd
nome , pr , pc , tr , tc = [],[],[],[],[]
td=pd.DataFrame()
for i in range(len(data_json["response"]["TrsrBdTradgList"])):
  nome.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['nm'])
  pr.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['untrRedVal'])
  pc.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['untrInvstmtVal'])
  tr.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['anulRedRate'])
  tc.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['anulInvstmtRate'])

td['título'] = nome
td['preço resgate'] = pr
td['preço compra'] = pc
td['taxa resgate'] = tr
td['taxa compra'] = tc

td['Ano'] = td['título'].str.extract(r'\b(\d{4})\b')
td = td.sort_values(by=['título','Ano'], ascending=True)
td.drop(['Ano'],axis=1,inplace=True)

td
# Out:
#                                          título  preço resgate  preço compra  \
# 20                          Tesouro Educa+ 2026        3432.01       3446.37
# 21                          Tesouro Educa+ 2027        3241.90       3259.13
# 23                          Tesouro Educa+ 2028        3061.59       3081.33
# 24                          Tesouro Educa+ 2029        2892.22       2914.16
# 25                          Tesouro Educa+ 2030        2729.94       2753.75
# 28                          Tesouro Educa+ 2031        2573.63       2599.01
# 29                          Tesouro Educa+ 2032        2426.42       2453.11
# 30                          Tesouro Educa+ 2033        2290.06       2317.86
# 31                          Tesouro Educa+ 2034        2162.07       2190.78
# 32                          Tesouro Educa+ 2035        2044.01       2073.48
# 34                          Tesouro Educa+ 2036        1930.28       1960.32
# 35                          Tesouro Educa+ 2037        1820.65       1851.07
# 36                          Tesouro Educa+ 2038        1714.74       1745.35
# 37                          Tesouro Educa+ 2039        1612.04       1642.67
# 38                          Tesouro Educa+ 2040        1512.51       1542.97
# 41                          Tesouro Educa+ 2041        1415.93       1446.06
# 42                          Tesouro Educa+ 2042        1324.61       1354.30
# 53      Tesouro IGPM+ com Juros Semestrais 2031        8196.23          0.00
# 16                           Tesouro IPCA+ 2026        3803.83          0.00
# 18                           Tesouro IPCA+ 2029        3248.56       3265.78
# 26                           Tesouro IPCA+ 2035        2295.31       2323.13
# 39                           Tesouro IPCA+ 2045        1243.36       1272.64
# 17      Tesouro IPCA+ com Juros Semestrais 2026        4276.01          0.00
# 19      Tesouro IPCA+ com Juros Semestrais 2030        4310.02          0.00
# 22      Tesouro IPCA+ com Juros Semestrais 2032        4298.79          0.00
# 27      Tesouro IPCA+ com Juros Semestrais 2035        4358.01       4397.15
# 33      Tesouro IPCA+ com Juros Semestrais 2040        4312.87       4364.34
# 40      Tesouro IPCA+ com Juros Semestrais 2045        4317.77          0.00
# 44      Tesouro IPCA+ com Juros Semestrais 2050        4235.37          0.00
# 46      Tesouro IPCA+ com Juros Semestrais 2055        4310.79       4380.13
# 5                        Tesouro Prefixado 2025         964.82          0.00
# 7                        Tesouro Prefixado 2026         863.72          0.00
# 8                        Tesouro Prefixado 2027         775.36        777.31
# 10                       Tesouro Prefixado 2029         621.16          0.00
# 12                       Tesouro Prefixado 2031         496.05        499.42
# 6   Tesouro Prefixado com Juros Semestrais 2025        1011.75          0.00
# 9   Tesouro Prefixado com Juros Semestrais 2027         986.89          0.00
# 11  Tesouro Prefixado com Juros Semestrais 2029         964.46          0.00
# 13  Tesouro Prefixado com Juros Semestrais 2031         945.08          0.00
# 14  Tesouro Prefixado com Juros Semestrais 2033         933.25          0.00
# 15  Tesouro Prefixado com Juros Semestrais 2035         921.32        927.69
# 43      Tesouro Renda+ Aposentadoria Extra 2030        1845.15       1873.23
# 45      Tesouro Renda+ Aposentadoria Extra 2035        1365.76       1394.35
# 47      Tesouro Renda+ Aposentadoria Extra 2040        1008.05       1034.94
# 48      Tesouro Renda+ Aposentadoria Extra 2045         742.07        766.14
# 49      Tesouro Renda+ Aposentadoria Extra 2050         551.52        572.62
# 50      Tesouro Renda+ Aposentadoria Extra 2055         410.28        428.37
# 51      Tesouro Renda+ Aposentadoria Extra 2060         303.00        318.15
# 52      Tesouro Renda+ Aposentadoria Extra 2065         224.60        237.16
# 0                            Tesouro Selic 2024       15264.21          0.00
# 1                            Tesouro Selic 2025       15266.80          0.00
# 2                            Tesouro Selic 2026       15260.27          0.00
# 3                            Tesouro Selic 2027       15235.13      15238.91
# 4                            Tesouro Selic 2029       15156.06      15162.84
#
#     taxa resgate  taxa compra
# 20        6.2900       6.1700
# 21        6.2100       6.0900
# 23        6.1600       6.0400
# 24        6.1200       6.0000
# 25        6.1000       5.9800
# 28        6.1000       5.9800
# 29        6.1000       5.9800
# 30        6.0900       5.9700
# 31        6.0800       5.9600
# 32        6.0600       5.9400
# 34        6.0500       5.9300
# 35        6.0500       5.9300
# 36        6.0600       5.9400
# 37        6.0800       5.9600
# 38        6.1100       5.9900
# 41        6.1500       6.0300
# 42        6.1900       6.0700
# 53        6.1400       0.0000
# 16        6.6400       0.0000
# 18        6.2600       6.1400
# 26        6.1100       5.9900
# 39        6.2300       6.1100
# 17        6.6400       0.0000
# 19        6.1100       0.0000
# 22        6.1300       0.0000
# 27        6.1300       6.0100
# 33        6.0600       5.9400
# 40        6.1800       0.0000
# 44        6.2000       0.0000
# 46        6.1700       6.0500
# 5        10.8000       0.0000
# 7        11.4700       0.0000
# 8        11.5000      11.3800
# 10       11.6600       0.0000
# 12       11.7600      11.6400
# 6        10.8500       0.0000
# 9        11.5000       0.0000
# 11       11.6500       0.0000
# 13       11.7300       0.0000
# 14       11.6800       0.0000
# 15       11.7100      11.5900
# 43        6.1300       6.0100
# 45        6.1600       6.0400
# 47        6.1900       6.0700
# 48        6.2200       6.1000
# 49        6.2100       6.0900
# 50        6.2000       6.0800
# 51        6.2100       6.0900
# 52        6.2100       6.0900
# 0         0.0372       0.0000
# 1        -0.0318       0.0000
# 2         0.0175       0.0000
# 3         0.0769       0.0669
# 4         0.1591       0.1491

# %%
# Gravar os dados em um arquivo .json
# os dados da ultima atualização ficam disponiveis no github

with open('data/tesouro_direto.json', 'w', encoding='utf-8') as json_file:
    json.dump(data_json, json_file, ensure_ascii=False, indent=4)

print("Dados gravados em 'tesouro_direto.json'",end=' ')

from datetime import datetime
now = datetime.now()
print("em ", now.strftime("%d-%m-%Y %H:%M:%S"))
# Out:
# Dados gravados em 'tesouro_direto.json' em  26-08-2024 17:55:12

# %% [markdown]
# os dados da ultima atualização ficam disponiveis no github
#
# https://raw.githubusercontent.com/BDonadelli/Finance-playground/main/data/tesouro_direto.json

# %%
## escreva numa planilha (privada)

import gspread
from oauth2client.service_account import ServiceAccountCredentials

scope = ['https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/spreadsheets']
jfile = 'carteira-328314-d38dcc8ee3e4.json'

credentials = ServiceAccountCredentials.from_json_keyfile_name(jfile, scope)
gc = gspread.authorize(credentials)


from datetime import datetime

# %%
titulo_planilha = 'Investimentos'
planilha = gc.open(titulo_planilha)
atualiza_saldos = True
pagina = planilha.worksheet('Renda Fixa')

# %%
from datetime import date
today = date.today().strftime('%d/%m/%Y')

linha = int(input('linha da celula inicial 81)'))
pagina.update(range_name= 'a'+str(linha),  values=[[today]] )

pagina.update(range_name='a'+str(linha+1),values=[td.columns.values.tolist()] + td.values.tolist())
# Out:
# {'spreadsheetId': '1Mse441x9H8uByQkSTVngIKUmH5iBFwEuhGjo1LhqGE8',
#  'updatedRange': "'Renda Fixa'!A82:E136",
#  'updatedRows': 55,
#  'updatedColumns': 5,
#  'updatedCells': 275}
