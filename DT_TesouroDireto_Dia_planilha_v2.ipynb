# %%
##  Lê a pagina web da url

url = 'https://www.tesourodireto.com.br/json/br/com/b3/tesourodireto/service/api/treasurybondsinfo.json'

from selenium import webdriver
driver=webdriver.Chrome()
driver.get(url)

## separa o que interessa

page_source = driver.page_source
start = page_source.find("{")
end = page_source.rfind("}") + 1
json_text = page_source[start:end]

import json
data_json = json.loads(json_text)

# %%
driver.close()

# %%
## organiza a informação

import pandas as pd
nome , pr , pc , tr , tc = [],[],[],[],[]
td=pd.DataFrame()
for i in range(len(data_json["response"]["TrsrBdTradgList"])):
  nome.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['nm'])
  pr.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['untrRedVal'])
  pc.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['untrInvstmtVal'])
  tr.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['anulRedRate'])
  tc.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['anulInvstmtRate'])

td['título'] = nome
td['preço resgate'] = pr
td['preço compra'] = pc
td['taxa resgate'] = tr
td['taxa compra'] = tc

td['Ano'] = td['título'].str.extract(r'\b(\d{4})\b')
td = td.sort_values(by=['título','Ano'], ascending=True)
td.drop(['Ano'],axis=1,inplace=True)

td
# Out:
#                                          título  preço resgate  preço compra  \
# 17                          Tesouro Educa+ 2026        3399.52       3412.06
# 18                          Tesouro Educa+ 2027        3157.47       3172.62
# 20                          Tesouro Educa+ 2028        2935.22       2952.59
# 21                          Tesouro Educa+ 2029        2732.29       2751.51
# 22                          Tesouro Educa+ 2030        2543.54       2564.28
# 25                          Tesouro Educa+ 2031        2366.05       2388.01
# 26                          Tesouro Educa+ 2032        2205.73       2228.68
# 27                          Tesouro Educa+ 2033        2061.88       2085.66
# 28                          Tesouro Educa+ 2034        1931.92       1956.39
# 29                          Tesouro Educa+ 2035        1814.54       1839.57
# 31                          Tesouro Educa+ 2036        1708.54       1734.06
# 32                          Tesouro Educa+ 2037        1604.97       1630.78
# 33                          Tesouro Educa+ 2038        1502.95       1528.83
# 34                          Tesouro Educa+ 2039        1401.70       1427.43
# 35                          Tesouro Educa+ 2040        1303.17       1328.57
# 38                          Tesouro Educa+ 2041        1209.16       1234.08
# 39                          Tesouro Educa+ 2042        1119.37       1143.71
# 50      Tesouro IGPM+ com Juros Semestrais 2031        7800.94          0.00
# 13                           Tesouro IPCA+ 2026        3887.63          0.00
# 15                           Tesouro IPCA+ 2029        3169.34       3184.63
# 23                           Tesouro IPCA+ 2035        2054.92       2078.64
# 36                           Tesouro IPCA+ 2045        1041.68       1065.52
# 14      Tesouro IPCA+ com Juros Semestrais 2026        4376.36          0.00
# 16      Tesouro IPCA+ com Juros Semestrais 2030        4166.78          0.00
# 19      Tesouro IPCA+ com Juros Semestrais 2032        4085.90          0.00
# 24      Tesouro IPCA+ com Juros Semestrais 2035        3935.31       3968.81
# 30      Tesouro IPCA+ com Juros Semestrais 2040        3979.21       4022.81
# 37      Tesouro IPCA+ com Juros Semestrais 2045        3807.02          0.00
# 41      Tesouro IPCA+ com Juros Semestrais 2050        3786.30          0.00
# 43      Tesouro IPCA+ com Juros Semestrais 2055        3692.48       3746.12
# 4                        Tesouro Prefixado 2026         869.55          0.00
# 5                        Tesouro Prefixado 2027         750.59        752.14
# 7                        Tesouro Prefixado 2029         566.69          0.00
# 9                        Tesouro Prefixado 2031         430.53        433.21
# 6   Tesouro Prefixado com Juros Semestrais 2027         915.05          0.00
# 8   Tesouro Prefixado com Juros Semestrais 2029         852.83          0.00
# 10  Tesouro Prefixado com Juros Semestrais 2031         811.38          0.00
# 11  Tesouro Prefixado com Juros Semestrais 2033         784.69          0.00
# 12  Tesouro Prefixado com Juros Semestrais 2035         767.65        772.51
# 40      Tesouro Renda+ Aposentadoria Extra 2030        1637.42       1660.67
# 42      Tesouro Renda+ Aposentadoria Extra 2035        1157.00       1180.00
# 44      Tesouro Renda+ Aposentadoria Extra 2040         811.75        832.51
# 45      Tesouro Renda+ Aposentadoria Extra 2045         562.40        579.97
# 46      Tesouro Renda+ Aposentadoria Extra 2050         393.69        408.25
# 47      Tesouro Renda+ Aposentadoria Extra 2055         277.52        289.39
# 48      Tesouro Renda+ Aposentadoria Extra 2060         194.43        203.87
# 49      Tesouro Renda+ Aposentadoria Extra 2065         136.23        143.65
# 0                            Tesouro Selic 2025       15842.24          0.00
# 1                            Tesouro Selic 2026       15836.25          0.00
# 2                            Tesouro Selic 2027       15815.91      15819.26
# 3                            Tesouro Selic 2029       15746.47      15752.95
#
#     taxa resgate  taxa compra
# 17        7.8600       7.7400
# 18        7.8300       7.7100
# 20        7.7900       7.6700
# 21        7.7400       7.6200
# 22        7.7000       7.5800
# 25        7.6800       7.5600
# 26        7.6400       7.5200
# 27        7.5800       7.4600
# 28        7.5100       7.3900
# 29        7.4300       7.3100
# 31        7.3400       7.2200
# 32        7.2800       7.1600
# 33        7.2500       7.1300
# 34        7.2500       7.1300
# 35        7.2700       7.1500
# 38        7.3000       7.1800
# 39        7.3400       7.2200
# 50        7.7600       0.0000
# 13        7.8800       0.0000
# 15        7.8400       7.7200
# 23        7.6600       7.5400
# 36        7.3700       7.2500
# 14        7.8500       0.0000
# 16        7.7600       0.0000
# 19        7.7200       0.0000
# 24        7.6800       7.5600
# 30        7.3400       7.2200
# 37        7.4300       0.0000
# 41        7.4900       0.0000
# 43        7.4700       7.3500
# 4        15.1300       0.0000
# 5        15.5900      15.4700
# 7        15.4200       0.0000
# 9        15.2200      15.1000
# 6        15.5500       0.0000
# 8        15.4800       0.0000
# 10       15.2700       0.0000
# 11       15.0200       0.0000
# 12       14.8100      14.6900
# 40        7.4500       7.3300
# 42        7.3900       7.2700
# 44        7.3900       7.2700
# 45        7.4400       7.3200
# 46        7.4400       7.3200
# 47        7.4200       7.3000
# 48        7.4200       7.3000
# 49        7.4200       7.3000
# 0         0.0258       0.0000
# 1         0.0365       0.0000
# 2         0.0800       0.0700
# 3         0.1483       0.1383

# %%
# Gravar os dados em um arquivo .json
# os dados da ultima atualização ficam disponiveis no github

with open('data/tesouro_direto.json', 'w', encoding='utf-8') as json_file:
    json.dump(data_json, json_file, ensure_ascii=False, indent=4)

print("Dados gravados em 'tesouro_direto.json'",end=' ')

from datetime import datetime
now = datetime.now()
print("em ", now.strftime("%d-%m-%Y %H:%M:%S"))
# Out:
# Dados gravados em 'tesouro_direto.json' em  05-01-2025 22:59:42

# %% [markdown]
# os dados da ultima atualização ficam disponiveis no github
#
# https://raw.githubusercontent.com/BDonadelli/Finance-playground/main/data/tesouro_direto.json

# %%
## escreva numa planilha (privada)

import gspread
from oauth2client.service_account import ServiceAccountCredentials

scope = ['https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/spreadsheets']
jfile = 'carteira-328314-d38dcc8ee3e4.json'

credentials = ServiceAccountCredentials.from_json_keyfile_name(jfile, scope)
gc = gspread.authorize(credentials)


from datetime import datetime

# %%
titulo_planilha = 'Investimentos'
planilha = gc.open(titulo_planilha)
atualiza_saldos = True
pagina = planilha.worksheet('Renda Fixa')

# %%
from datetime import date
today = date.today().strftime('%d/%m/%Y')

# linha = int(input('linha da celula inicial 81)'))
pagina.update(range_name= 'u'+str(91),  values=[[today]] )

pagina.update(range_name='u'+str(92),values=[td.columns.values.tolist()] + td.values.tolist())
# Out:
# {'spreadsheetId': '1Mse441x9H8uByQkSTVngIKUmH5iBFwEuhGjo1LhqGE8',
#  'updatedRange': "'Renda Fixa'!U92:Y143",
#  'updatedRows': 52,
#  'updatedColumns': 5,
#  'updatedCells': 260}
