# %%
import yfinance as yf
from datetime import datetime, timedelta

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
petr = yf.Ticker("PETR4.SA")

# %%
petr.history(period="max")
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2000-01-03 00:00:00-02:00   1.402439   1.402439   1.402439   1.402439
# 2000-01-04 00:00:00-02:00   1.324858   1.324858   1.324858   1.324858
# 2000-01-05 00:00:00-02:00   1.311490   1.311490   1.311490   1.311490
# 2000-01-06 00:00:00-02:00   1.306955   1.306955   1.306955   1.306955
# 2000-01-07 00:00:00-02:00   1.312922   1.312922   1.312922   1.312922
# ...                              ...        ...        ...        ...
# 2024-08-05 00:00:00-03:00  34.799999  35.700001  34.599998  35.700001
# 2024-08-06 00:00:00-03:00  35.599998  36.660000  35.340000  36.320000
# 2024-08-07 00:00:00-03:00  36.700001  36.750000  36.000000  36.270000
# 2024-08-08 00:00:00-03:00  36.349998  36.950001  36.160000  36.849998
# 2024-08-09 00:00:00-03:00  36.130001  36.950001  35.580002  36.509998
#
#                                 Volume  Dividends  Stock Splits
# Date
# ...

# %%
petr.history(period="max")["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
petr.info
# Out:
# {'address1': 'Avenida Henrique Valadares, 28',
#  'address2': '19th floor',
#  'city': 'Rio De Janeiro',
#  'state': 'RJ',
#  'zip': '20241-030',
#  'country': 'Brazil',
#  'website': 'https://petrobras.com.br',
#  'industry': 'Oil & Gas Integrated',
#  'industryKey': 'oil-gas-integrated',
#  'industryDisp': 'Oil & Gas Integrated',
#  'sector': 'Energy',
#  'sectorKey': 'energy',
#  'sectorDisp': 'Energy',
# ...

# %%
petr.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2005-04-01 00:00:00-03:00   0.133288           0.0
# 2005-07-01 00:00:00-03:00   0.250663           0.0
# 2005-09-01 00:00:00-03:00   0.000000           4.0
# 2006-01-02 00:00:00-02:00   0.259000           0.0
# 2006-04-04 00:00:00-03:00   0.132700           0.0
# 2006-11-01 00:00:00-03:00   0.500750           0.0
# 2007-01-02 00:00:00-02:00   0.225000           0.0
# 2007-04-03 00:00:00-03:00   0.175000           0.0
# 2007-08-20 00:00:00-03:00   0.251700           0.0
# 2007-10-08 00:00:00-03:00   0.256500           0.0
# 2008-01-14 00:00:00-02:00   0.155300           0.0
# 2008-04-07 00:00:00-03:00   0.102600           0.0
# 2008-04-28 00:00:00-03:00   0.000000           2.0
# 2008-12-29 00:00:00-02:00   0.042600           0.0
# 2009-04-09 00:00:00-03:00   0.351600           0.0
# 2009-07-06 00:00:00-03:00   0.300000           0.0
# 2009-10-01 00:00:00-03:00   0.200000           0.0
# ...

# %%
petr.financials
petr.quarterly_financials
# Out:
#                                                            2024-03-31  \
# Tax Effect Of Unusual Items                         -331067894.131185
# Tax Rate For Calcs                                           0.308832
# Normalized EBITDA                                       12383000000.0
# Total Unusual Items                                     -1072000000.0
# Total Unusual Items Excluding Goodwill                  -1072000000.0
# Net Income From Continuing Operation Net Minori...       4782000000.0
# Reconciled Depreciation                                  3362000000.0
# Reconciled Cost Of Revenue                               8357000000.0
# EBITDA                                                  11311000000.0
# EBIT                                                     7949000000.0
# Net Interest Income                                      -952000000.0
# Interest Expense                                          997000000.0
# ...

# %%
# show major holders
try:
    petr.major_holders
except:
    pass

# %%
# show institutional holders
petr.institutional_holders
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# show cashflow
petr.cashflow
# Out:
#                                             2023-12-31     2022-12-31  \
# Free Cash Flow                           31098000000.0  40136000000.0
# Repurchase Of Capital Stock               -735000000.0            0.0
# Repayment Of Debt                       -10479000000.0 -14764000000.0
# Issuance Of Debt                          2210000000.0   2880000000.0
# Capital Expenditure                     -12114000000.0  -9581000000.0
# ...                                                ...            ...
# Operating Gains Losses                    3049000000.0   4390000000.0
# Pension And Employee Benefit Expense      1542000000.0   1228000000.0
# Earnings Losses From Equity Investments    304000000.0   -251000000.0
# Net Foreign Currency Exchange Gain Loss   2498000000.0   4557000000.0
# Net Income From Continuing Operations    24995000000.0  36755000000.0
#
#                                             2021-12-31     2020-12-31  \
# ...

# %%
petr.quarterly_cashflow
# Out:
#                                            2024-03-31    2023-12-31  \
# Free Cash Flow                           6548000000.0  8075000000.0
# Repurchase Of Capital Stock              -232000000.0  -538000000.0
# Repayment Of Debt                       -2925000000.0 -3503000000.0
# Issuance Of Debt                            2000000.0   910000000.0
# Capital Expenditure                     -2838000000.0 -3594000000.0
# ...                                               ...           ...
# Operating Gains Losses                   2299000000.0    -3000000.0
# Pension And Employee Benefit Expense      433000000.0   389000000.0
# Earnings Losses From Equity Investments    93000000.0    69000000.0
# Net Foreign Currency Exchange Gain Loss  1935000000.0  -316000000.0
# Net Income From Continuing Operations    4805000000.0  6282000000.0
#
#                                            2023-09-30    2023-06-30  \
# Free Cash Flow                           8369000000.0  6730000000.0
# ...

# %%
petr.balance_sheet
# Out:
#                                                      2023-12-31  \
# Treasury Shares Number                              104359669.0
# Preferred Shares Number                                     NaN
# Ordinary Shares Number                            12940137261.0
# Share Issued                                      13044496930.0
# Net Debt                                          16074000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  15546000000.0
# Other Short Term Investments                       2819000000.0
# Cash And Cash Equivalents                         12727000000.0
# Cash Equivalents                                  12624000000.0
# Cash Financial                                      103000000.0
#
#                                                      2022-12-31  \
# Treasury Shares Number                                 295669.0
# Preferred Shares Number                                     NaN
# ...

# %%
petr.quarterly_balance_sheet
# Out:
#                                                      2024-03-31  \
# Treasury Shares Number                              135209269.0
# Ordinary Shares Number                            12909287661.0
# Share Issued                                      13044496930.0
# Net Debt                                          16191000000.0
# Total Debt                                        61838000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  16365000000.0
# Other Short Term Investments                       4818000000.0
# Cash And Cash Equivalents                         11547000000.0
# Cash Equivalents                                  10824000000.0
# Cash Financial                                      723000000.0
#
#                                                      2023-12-31  \
# Treasury Shares Number                              104359669.0
# Ordinary Shares Number                            12940137261.0
# ...

# %%
try :
    petr.earnings
except:
    pass

# %%
try:
    petr.quarterly_earnings
except:
    pass

# %%
today = datetime.today().strftime('%Y-%m-%d')
today_minus_7 = (datetime.today() - timedelta(days=7)).strftime('%Y-%m-%d')
data = petr.history(interval='1m', start=today_minus_7, end=today)

# %%
data
# Out:
#                                 Open       High        Low      Close  Volume  \
# Datetime
# 2024-08-05 10:08:00-03:00  34.799999  34.849998  34.770000  34.849998       0
# 2024-08-05 10:09:00-03:00  34.849998  34.849998  34.700001  34.700001  171300
# 2024-08-05 10:10:00-03:00  34.720001  34.849998  34.660000  34.810001  363200
# 2024-08-05 10:11:00-03:00  34.830002  34.889999  34.759998  34.820000  320400
# 2024-08-05 10:12:00-03:00  34.810001  34.990002  34.799999  34.980000  433700
# ...                              ...        ...        ...        ...     ...
# 2024-08-09 16:50:00-03:00  36.509998  36.529999  36.500000  36.509998  103000
# 2024-08-09 16:51:00-03:00  36.509998  36.529999  36.500000  36.509998   94700
# 2024-08-09 16:52:00-03:00  36.500000  36.509998  36.470001  36.480000   79300
# 2024-08-09 16:53:00-03:00  36.480000  36.490002  36.439999  36.459999  233300
# 2024-08-09 16:54:00-03:00  36.439999  36.490002  36.439999  36.480000   88000
#
# ...

# %%
acoes = 'PETR4.SA ABEV3.SA VALE3.SA'

# %%
tickers = yf.Tickers(acoes)

# %%
tickers.tickers["PETR4.SA"].balance_sheet
# Out:
#                                                      2023-12-31  \
# Treasury Shares Number                              104359669.0
# Preferred Shares Number                                     NaN
# Ordinary Shares Number                            12940137261.0
# Share Issued                                      13044496930.0
# Net Debt                                          16074000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  15546000000.0
# Other Short Term Investments                       2819000000.0
# Cash And Cash Equivalents                         12727000000.0
# Cash Equivalents                                  12624000000.0
# Cash Financial                                      103000000.0
#
#                                                      2022-12-31  \
# Treasury Shares Number                                 295669.0
# Preferred Shares Number                                     NaN
# ...

# %%
tickers = yf.Tickers(acoes.split())
tickers.tickers
# Out:
# {'PETR4.SA': yfinance.Ticker object <PETR4.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'VALE3.SA': yfinance.Ticker object <VALE3.SA>}

# %%
dict_data = {}

for ticker in tickers.tickers.keys():
    print("Baixando: {}".format(ticker))
    dict_data[ticker] = tickers.tickers[ticker].history(period="max")
# Out:
# Baixando: PETR4.SA
# Baixando: ABEV3.SA
# Baixando: VALE3.SA

# %%
dict_data["PETR4.SA"]
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2000-01-03 00:00:00-02:00   1.402440   1.402440   1.402440   1.402440
# 2000-01-04 00:00:00-02:00   1.324858   1.324858   1.324858   1.324858
# 2000-01-05 00:00:00-02:00   1.311490   1.311490   1.311490   1.311490
# 2000-01-06 00:00:00-02:00   1.306955   1.306955   1.306955   1.306955
# 2000-01-07 00:00:00-02:00   1.312922   1.312922   1.312922   1.312922
# ...                              ...        ...        ...        ...
# 2024-08-05 00:00:00-03:00  34.799999  35.700001  34.599998  35.700001
# 2024-08-06 00:00:00-03:00  35.599998  36.660000  35.340000  36.320000
# 2024-08-07 00:00:00-03:00  36.700001  36.750000  36.000000  36.270000
# 2024-08-08 00:00:00-03:00  36.349998  36.950001  36.160000  36.849998
# 2024-08-09 00:00:00-03:00  36.130001  36.950001  35.580002  36.509998
#
#                                 Volume  Dividends  Stock Splits
# Date
# ...

# %%
dict_data[ticker]["Close"]
# Out:
# Date
# 2000-01-03 00:00:00-02:00     1.477964
# 2000-01-04 00:00:00-02:00     1.442774
# 2000-01-05 00:00:00-02:00     1.442774
# 2000-01-06 00:00:00-02:00     1.442774
# 2000-01-07 00:00:00-02:00     1.495558
#                                ...
# 2024-08-05 00:00:00-03:00    57.020000
# 2024-08-06 00:00:00-03:00    57.310001
# 2024-08-07 00:00:00-03:00    57.200001
# 2024-08-08 00:00:00-03:00    56.849998
# 2024-08-09 00:00:00-03:00    57.060001
# Name: Close, Length: 6180, dtype: float64

# %%
df_data = pd.DataFrame()

for ticker in dict_data.keys():
    df_aux = dict_data[ticker].rename(columns={"Close": ticker})
    df_data = df_data.join(df_aux[ticker], how="outer")

df_data
# Out:
#                             PETR4.SA   ABEV3.SA   VALE3.SA
# Date
# 2000-01-03 00:00:00-02:00   1.402440        NaN   1.477964
# 2000-01-04 00:00:00-02:00   1.324858        NaN   1.442774
# 2000-01-05 00:00:00-02:00   1.311490   0.290351   1.442774
# 2000-01-06 00:00:00-02:00   1.306955   0.275633   1.442774
# 2000-01-07 00:00:00-02:00   1.312922   0.275633   1.495558
# ...                              ...        ...        ...
# 2024-08-05 00:00:00-03:00  35.700001  11.850000  57.020000
# 2024-08-06 00:00:00-03:00  36.320000  12.010000  57.310001
# 2024-08-07 00:00:00-03:00  36.270000  12.510000  57.200001
# 2024-08-08 00:00:00-03:00  36.849998  12.360000  56.849998
# 2024-08-09 00:00:00-03:00  36.509998  12.450000  57.060001
#
# [6180 rows x 3 columns]

# %%
df_data
# Out:
#                             PETR4.SA   ABEV3.SA   VALE3.SA
# Date
# 2000-01-03 00:00:00-02:00   1.402440        NaN   1.477964
# 2000-01-04 00:00:00-02:00   1.324858        NaN   1.442774
# 2000-01-05 00:00:00-02:00   1.311490   0.290351   1.442774
# 2000-01-06 00:00:00-02:00   1.306955   0.275633   1.442774
# 2000-01-07 00:00:00-02:00   1.312922   0.275633   1.495558
# ...                              ...        ...        ...
# 2024-08-05 00:00:00-03:00  35.700001  11.850000  57.020000
# 2024-08-06 00:00:00-03:00  36.320000  12.010000  57.310001
# 2024-08-07 00:00:00-03:00  36.270000  12.510000  57.200001
# 2024-08-08 00:00:00-03:00  36.849998  12.360000  56.849998
# 2024-08-09 00:00:00-03:00  36.509998  12.450000  57.060001
#
# [6180 rows x 3 columns]

# %%
df_ret = df_data / df_data.shift(1) - 1

# %% [markdown]
# #####  pior retorno

# %%
df_ret.idxmin()
# Out:
# PETR4.SA   2020-03-09 00:00:00-03:00
# ABEV3.SA   2005-04-04 00:00:00-03:00
# VALE3.SA   2019-01-28 00:00:00-02:00
# dtype: datetime64[ns, America/Sao_Paulo]

# %%
df_ret.min()
# Out:
# PETR4.SA   -0.296978
# ABEV3.SA   -0.224263
# VALE3.SA   -0.245592
# dtype: float64

# %%
df_ret
# Out:
#                            PETR4.SA  ABEV3.SA  VALE3.SA
# Date
# 2000-01-03 00:00:00-02:00       NaN       NaN       NaN
# 2000-01-04 00:00:00-02:00 -0.055319       NaN -0.023810
# 2000-01-05 00:00:00-02:00 -0.010090       NaN  0.000000
# 2000-01-06 00:00:00-02:00 -0.003458 -0.050691  0.000000
# 2000-01-07 00:00:00-02:00  0.004566  0.000000  0.036585
# ...                             ...       ...       ...
# 2024-08-05 00:00:00-03:00 -0.000840 -0.001685 -0.005168
# 2024-08-06 00:00:00-03:00  0.017367  0.013502  0.005086
# 2024-08-07 00:00:00-03:00 -0.001377  0.041632 -0.001919
# 2024-08-08 00:00:00-03:00  0.015991 -0.011990 -0.006119
# 2024-08-09 00:00:00-03:00 -0.009227  0.007282  0.003694
#
# [6180 rows x 3 columns]

# %% [markdown]
# #### retornos do dia seguinte a uma queda

# %%
df_ret[df_ret.shift(1) < 0].mean()
# Out:
# PETR4.SA    0.000582
# ABEV3.SA    0.001083
# VALE3.SA    0.000361
# dtype: float64

# %%
df_ret[df_ret.shift(1) < 0].std()
# Out:
# PETR4.SA    0.028416
# ABEV3.SA    0.018317
# VALE3.SA    0.025389
# dtype: float64

# %%
df_study = df_ret[df_ret.shift(1) < 0]

print("Média e desvio padrão dos retornos após dias de queda")
for acao in acoes.split():
    print(f'{acao} - {df_study[acao].mean()*100} - {df_study[acao].std()*10}')

fig, ax = plt.subplots(figsize=(20, 8))
sns.histplot(df_study, kde=True)
# Out:
# Média e desvio padrão dos retornos após dias de queda
# PETR4.SA - 0.058171192203505404 - 0.284164414715306
# ABEV3.SA - 0.10825557380005589 - 0.18317242347642174
# VALE3.SA - 0.036077504748004134 - 0.25389003564877816
# <Axes: ylabel='Count'>

# %% [markdown]
# #### se as quedas foram  maiores que 5%.

# %%
df_study = df_ret[df_ret.shift(1) < -0.05]


print("Média e desvio padrão dos retornos após dias de queda")
for acao in acoes.split():
    print(f'{acao} - {df_study[acao].mean()*100} - {df_study[acao].std()*10}')



fig, ax = plt.subplots(figsize=(20, 8))
sns.histplot(df_study, kde=True)
# Out:
# Média e desvio padrão dos retornos após dias de queda
# PETR4.SA - 0.10531309231822654 - 0.5853509751345067
# ABEV3.SA - 1.1917902020261726 - 0.42781456484753577
# VALE3.SA - 0.21409655289866486 - 0.4889395055458176
# <Axes: ylabel='Count'>
