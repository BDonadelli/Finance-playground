# %% [markdown]
# <a href="https://colab.research.google.com/github/BDonadelli/Codigos-em-financas/blob/main/TesouroDireto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlopen
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import json
url = 'https://www.tesourodireto.com.br/json/br/com/b3/tesourodireto/service/api/treasurybondsinfo.json'
response = urlopen(url)
data_json = json.loads(response.read())

# %%
nome , pr , pc , tr , tc = [],[],[],[],[]
td=pd.DataFrame()

for i in range(len(data_json["response"]["TrsrBdTradgList"])):
  nome.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['nm'])
  pr.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['untrRedVal'])
  pc.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['untrInvstmtVal'])
  tr.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['anulRedRate'])
  tc.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['anulInvstmtRate'])
td['título'] = nome
td['preço resgate'] = pr
td['preço compra'] = pc
td['taxa resgate'] = tr
td['taxa compra'] = tc

# %%
td
# Out:
#                                          título  preço resgate  preço compra  \
# 0                            Tesouro Selic 2024       13591.17          0.00
# 1                            Tesouro Selic 2025       13587.84          0.00
# 2                            Tesouro Selic 2026       13564.23      13567.72
# 3                            Tesouro Selic 2027       13527.09          0.00
# 4                            Tesouro Selic 2029       13463.20      13470.68
# 5                        Tesouro Prefixado 2024         906.28          0.00
# 6                        Tesouro Prefixado 2025         865.86          0.00
# 7   Tesouro Prefixado com Juros Semestrais 2025         998.24          0.00
# 8                        Tesouro Prefixado 2026         789.65        791.74
# 9   Tesouro Prefixado com Juros Semestrais 2027         999.97          0.00
# 10                       Tesouro Prefixado 2029         575.83        579.21
# 11  Tesouro Prefixado com Juros Semestrais 2029         983.21          0.00
# 12  Tesouro Prefixado com Juros Semestrais 2031         969.93          0.00
# 13  Tesouro Prefixado com Juros Semestrais 2033         957.99        964.46
# 14                           Tesouro IPCA+ 2024        3849.17          0.00
# 15      Tesouro IPCA+ com Juros Semestrais 2024        4202.35          0.00
# 16                           Tesouro IPCA+ 2026        3530.13          0.00
# 17      Tesouro IPCA+ com Juros Semestrais 2026        4314.57          0.00
# 18                           Tesouro IPCA+ 2029        3088.09       3108.47
# 19      Tesouro IPCA+ com Juros Semestrais 2030        4438.46          0.00
# 20      Tesouro IPCA+ com Juros Semestrais 2032        4451.61       4487.26
# 21                           Tesouro IPCA+ 2035        2239.79       2269.98
# 22      Tesouro IPCA+ com Juros Semestrais 2035        4418.49          0.00
# 23      Tesouro IPCA+ com Juros Semestrais 2040        4499.34       4555.41
# 24                           Tesouro IPCA+ 2045        1266.32       1297.98
# 25      Tesouro IPCA+ com Juros Semestrais 2045        4441.61          0.00
# 26      Tesouro Renda+ Aposentadoria Extra 2030        1810.95       1841.42
# 27      Tesouro IPCA+ com Juros Semestrais 2050        4513.69          0.00
# 28      Tesouro Renda+ Aposentadoria Extra 2035        1368.97       1399.87
# 29      Tesouro IPCA+ com Juros Semestrais 2055        4478.50       4555.98
# 30      Tesouro Renda+ Aposentadoria Extra 2040        1036.65       1066.04
# 31      Tesouro Renda+ Aposentadoria Extra 2045         786.51        813.40
# 32      Tesouro Renda+ Aposentadoria Extra 2050         601.44        625.54
# 33      Tesouro Renda+ Aposentadoria Extra 2055         460.32        481.49
# 34      Tesouro Renda+ Aposentadoria Extra 2060         351.17        369.40
# 35      Tesouro Renda+ Aposentadoria Extra 2065         267.91        283.43
# 36      Tesouro IGPM+ com Juros Semestrais 2031        8164.66          0.00
#
#     taxa resgate  taxa compra
# 0         0.0189       0.0000
# 1         0.0283       0.0000
# 2         0.0849       0.0749
# 3         0.1383       0.0000
# 4         0.1740       0.1640
# 5        11.4900       0.0000
# 6        10.6700       0.0000
# 7        10.7700       0.0000
# 8        10.2300      10.1100
# 9        10.3000       0.0000
# 10       10.7600      10.6400
# 11       10.6700       0.0000
# 12       10.8200       0.0000
# 13       10.9200      10.8000
# 14        6.9500       0.0000
# 15        6.9500       0.0000
# 16        5.2700       0.0000
# 17        5.3200       0.0000
# 18        5.1600       5.0400
# 19        5.1700       0.0000
# 20        5.2700       5.1500
# 21        5.3400       5.2200
# 22        5.3300       0.0000
# 23        5.4300       5.3100
# 24        5.5900       5.4700
# 25        5.5000       0.0000
# 26        5.4600       5.3400
# 27        5.5300       0.0000
# 28        5.5400       5.4200
# 29        5.5200       5.4000
# 30        5.5800       5.4600
# 31        5.6000       5.4800
# 32        5.5900       5.4700
# 33        5.5800       5.4600
# 34        5.5800       5.4600
# 35        5.5800       5.4600
# 36        5.8500       0.0000

# %%
import pandas as pd

import gspread

from google.colab import auth
auth.authenticate_user()

from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

planilha = gc.open('Dados')
sheet=planilha.get_worksheet(1)

# %%
sheet.update([td.columns.values.tolist()] + td.values.tolist())
# Out:
# {'spreadsheetId': '1hE0ThOaHSg3xdvm12rMSaMvcEFmbko3OcEJ_DwYO3Qo',
#  'updatedRange': "'Tesouro Direto'!A1:E38",
#  'updatedRows': 38,
#  'updatedColumns': 5,
#  'updatedCells': 190}
