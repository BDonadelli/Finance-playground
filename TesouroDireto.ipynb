# %% [markdown]
# <a href="https://colab.research.google.com/github/BDonadelli/Codigos-em-financas/blob/main/TesouroDireto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlopen
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import json
url = 'https://www.tesourodireto.com.br/json/br/com/b3/tesourodireto/service/api/treasurybondsinfo.json'
response = urlopen(url)
data_json = json.loads(response.read())

# %%
nome , pr , pc , tr , tc = [],[],[],[],[]
td=pd.DataFrame()

for i in range(len(data_json["response"]["TrsrBdTradgList"])):
  nome.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['nm'])
  pr.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['untrRedVal'])
  pc.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['untrInvstmtVal'])
  tr.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['anulRedRate'])
  tc.append(data_json["response"]["TrsrBdTradgList"][i]['TrsrBd']['anulInvstmtRate'])
td['título'] = nome
td['preço resgate'] = pr
td['preço compra'] = pc
td['taxa resgate'] = tr
td['taxa compra'] = tc

# %%
td
# Out:
#                                          título  preço resgate  preço compra  \
# 0                            Tesouro Selic 2024       13584.13          0.00
# 1                            Tesouro Selic 2025       13581.30          0.00
# 2                            Tesouro Selic 2026       13557.69      13561.19
# 3                            Tesouro Selic 2027       13519.57          0.00
# 4                            Tesouro Selic 2029       13455.82      13463.30
# 5                        Tesouro Prefixado 2024         905.52          0.00
# 6                        Tesouro Prefixado 2025         864.95          0.00
# 7   Tesouro Prefixado com Juros Semestrais 2025         997.23          0.00
# 8                        Tesouro Prefixado 2026         788.31        790.39
# 9   Tesouro Prefixado com Juros Semestrais 2027         997.16          0.00
# 10                       Tesouro Prefixado 2029         573.63        577.00
# 11  Tesouro Prefixado com Juros Semestrais 2029         979.78          0.00
# 12  Tesouro Prefixado com Juros Semestrais 2031         966.27          0.00
# 13  Tesouro Prefixado com Juros Semestrais 2033         953.85        960.28
# 14                           Tesouro IPCA+ 2024        3849.17          0.00
# 15      Tesouro IPCA+ com Juros Semestrais 2024        4202.29          0.00
# 16                           Tesouro IPCA+ 2026        3525.24          0.00
# 17      Tesouro IPCA+ com Juros Semestrais 2026        4309.05          0.00
# 18                           Tesouro IPCA+ 2029        3080.62       3100.97
# 19      Tesouro IPCA+ com Juros Semestrais 2030        4427.81          0.00
# 20      Tesouro IPCA+ com Juros Semestrais 2032        4438.78       4474.32
# 21                           Tesouro IPCA+ 2035        2231.79       2261.88
# 22      Tesouro IPCA+ com Juros Semestrais 2035        4406.63          0.00
# 23      Tesouro IPCA+ com Juros Semestrais 2040        4479.80       4535.56
# 24                           Tesouro IPCA+ 2045        1258.23       1289.68
# 25      Tesouro IPCA+ com Juros Semestrais 2045        4424.64          0.00
# 26      Tesouro Renda+ Aposentadoria Extra 2030        1800.50       1830.77
# 27      Tesouro IPCA+ com Juros Semestrais 2050        4489.05          0.00
# 28      Tesouro Renda+ Aposentadoria Extra 2035        1358.52       1389.15
# 29      Tesouro IPCA+ com Juros Semestrais 2055        4452.06       4528.85
# 30      Tesouro Renda+ Aposentadoria Extra 2040        1026.80       1055.89
# 31      Tesouro Renda+ Aposentadoria Extra 2045         779.75        806.39
# 32      Tesouro Renda+ Aposentadoria Extra 2050         595.43        619.27
# 33      Tesouro Renda+ Aposentadoria Extra 2055         456.78        477.78
# 34      Tesouro Renda+ Aposentadoria Extra 2060         349.61        367.76
# 35      Tesouro Renda+ Aposentadoria Extra 2065         266.59        282.03
# 36      Tesouro IGPM+ com Juros Semestrais 2031        8156.60          0.00
#
#     taxa resgate  taxa compra
# 0         0.0198       0.0000
# 1         0.0266       0.0000
# 2         0.0838       0.0738
# 3         0.1395       0.0000
# 4         0.1746       0.1646
# 5        11.5400       0.0000
# 6        10.7200       0.0000
# 7        10.8200       0.0000
# 8        10.2900      10.1700
# 9        10.3900       0.0000
# 10       10.8300      10.7100
# 11       10.7500       0.0000
# 12       10.8900       0.0000
# 13       10.9900      10.8700
# 14        6.9200       0.0000
# 15        6.9200       0.0000
# 16        5.3100       0.0000
# 17        5.3600       0.0000
# 18        5.2000       5.0800
# 19        5.2100       0.0000
# 20        5.3100       5.1900
# 21        5.3700       5.2500
# 22        5.3600       0.0000
# 23        5.4700       5.3500
# 24        5.6200       5.5000
# 25        5.5300       0.0000
# 26        5.5000       5.3800
# 27        5.5700       0.0000
# 28        5.5800       5.4600
# 29        5.5600       5.4400
# 30        5.6200       5.5000
# 31        5.6300       5.5100
# 32        5.6200       5.5000
# 33        5.6000       5.4800
# 34        5.5900       5.4700
# 35        5.5900       5.4700
# 36        5.8700       0.0000
